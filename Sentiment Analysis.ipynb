# %% [markdown]
# Für die Entwicklung des Klassifikators nutzen wir die Daten des SemEval 2013 Task 2b, ein Korpus mit 14882 annotierten Tweets:
#
# - Informationen zum Korpus: https://aclanthology.org/S13-2052/
# - Corpus als zip-Datei: [semeval2013.zip](https://moodle.zdv.uni-tuebingen.de/pluginfile.php/269639/mod_assign/introattachment/0/semeval2013.zip?forcedownload=1)

# %%
import nltk
import re
import string

from nltk import FreqDist
from nltk import MaxentClassifier
from nltk import ConditionalExponentialClassifier
from nltk import DecisionTreeClassifier
from nltk import WekaClassifier
from nltk import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.util import ngrams

from nltk import pos_tag

from nltk.stem import WordNetLemmatizer

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ngoc-\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ngoc-\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Ngoc-\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Ngoc-\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Zuerst lesen wir die Daten ein. Diese befinden sich in:
# - semeval2013/twitter-2013dev-A
# - semeval2013/twitter-2013test-A
# - semeval2013/twitter-2013train-A
#
# Wir entfernen alle Wörter, die mit "@", "#", "http" anfangen, und konvertieren alle unicode-escape-characters zu deren unicode-character.

# %%
with open('semeval2013/twitter-2013dev-A.txt', "r") as file:
    devlines = file.readlines()    
dev = [line.strip().split("\t") for line in devlines]
dev_ = dev

with open('semeval2013/twitter-2013test-A.txt', "r") as file:
    testlines = file.readlines()    
test = [line.strip().split("\t") for line in testlines]
test_ = test

with open('semeval2013/twitter-2013train-A.txt', "r") as file:
    trainlines = file.readlines()    
train = [line.strip().split("\t") for line in trainlines]
train_ = train

#konvertiere alle unicode-escapes zu unicode
def decode_unicode_escapes(text):
    try:
        return re.sub(r'\\[uU]([\dA-Fa-f]{4,8})', lambda m: chr(int(m.group(1), 16)), text)
    except:
        return " "

    
def remove_words(sentence):
    # Create a regular expression pattern to match words starting with "@" or "#" or "http"
    pattern = r'@\w+|#\w+|http?\S+'
    
    # Use the sub() function of the re module to replace all matched patterns with an empty string
    clean_sentence = re.sub(pattern, '', sentence)
    
    return clean_sentence    

dev = [[tag, sentiment, remove_words(decode_unicode_escapes(content))] for [tag, sentiment, content] in dev]
test = [[tag, sentiment, remove_words(decode_unicode_escapes(content))] for [tag, sentiment, content] in test]
train = [[tag, sentiment, remove_words(decode_unicode_escapes(content))] for [tag, sentiment, content] in train]
         
    
dev = [(tag, sentiment, ' '.join(word_tokenize(content))) for [tag, sentiment, content] in dev]
test = [(tag, sentiment, ' '.join(word_tokenize(content))) for [tag, sentiment, content] in test]
train = [(tag, sentiment, ' '.join(word_tokenize(content))) for [tag, sentiment, content] in train]


def generate_bigrams(tokens):
    bigrams = list(ngrams(tokens, 2))
    return [' '.join(bigram) for bigram in bigrams]


dev = [
    [tag, sentiment, ' '.join(word_tokenize(content)) + ' ' + ' '.join(generate_bigrams(word_tokenize(content)))]
    for [tag, sentiment, content] in dev
]
test = [
    [tag, sentiment, ' '.join(word_tokenize(content)) + ' ' + ' '.join(generate_bigrams(word_tokenize(content)))]
    for [tag, sentiment, content] in test
]
train = [
    [tag, sentiment, ' '.join(word_tokenize(content)) + ' ' + ' '.join(generate_bigrams(word_tokenize(content)))]
    for [tag, sentiment, content] in train
]

# %% [markdown]
# Anschließend lemmatisieren und stemmen wir alle Sätze

# %%
lemmatizer = WordNetLemmatizer()

sste = SnowballStemmer("english")

dev = [(tag, sentiment, ' '.join(str_val)) for tag, sentiment, str_val in [[lst[0], lst[1], [sste.stem(word) for word in lst[2].split()] ] for lst in dev]]
test = [(tag, sentiment, ' '.join(str_val)) for tag, sentiment, str_val in [[lst[0], lst[1], [sste.stem(word) for word in lst[2].split()] ] for lst in test]]
train = [(tag, sentiment, ' '.join(str_val)) for tag, sentiment, str_val in [[lst[0], lst[1], [sste.stem(word) for word in lst[2].split()] ] for lst in train]]



dev = [[lst[0], lst[1], ' '.join([lemmatizer.lemmatize(word) for word in lst[2].split()])] for lst in dev]
test = [[lst[0], lst[1], ' '.join([lemmatizer.lemmatize(word) for word in lst[2].split()])] for lst in test]
train = [[lst[0], lst[1], ' '.join([lemmatizer.lemmatize(word) for word in lst[2].split()])] for lst in train]

# %% [markdown]
# Zuerst zählen wir die Anzahl der Label für jedes der Datensplits. Anschließend normalisieren wir über die Anzahl der Tweets im jeweiligen Datensplit.

# %%
def count_sentiment(file):
    positive = 0
    neutral = 0
    negative = 0
    for [tag, sentiment, content] in file:
        if sentiment == "positive":
            positive += 1
        if sentiment == "neutral":
            neutral += 1
        if sentiment == "negative":
            negative += 1
    return [positive, neutral, negative]

def normalize_sentiment(file):
    result = [x / len(file) for x in count_sentiment(file)]
    return result
    
for file in [dev, test, train]:
    print(str(normalize_sentiment(file)))
# Out:
# [0.3476420798065296, 0.4467956469165659, 0.20556227327690446]
# [0.41584437552861575, 0.4265576543557936, 0.15759797011559065]
# [0.37587773647253203, 0.4735646427096241, 0.15055762081784388]

# %% [markdown]
# Da die Klassentypen ähnlich gleichmäßig über die Test/ Train/ Dev- Datensätze verteilt sind, ist der Train-Datensatz für das Training auf die Evaluierung des Test-Datensatzes geeignet. Hier ist ebenfalls erwähnenswert, dass positive und neutrale Tweets mit ungefähr doppelter Wahrscheinlichkeit auftreten als negative Tweets. Bereits ein zufälliges Zuweisen zwischen positiver Kategorie und negativer Kategorie würde somit in einer Accuracy von ca. 40% resultieren.

# %% [markdown]
# Um eine Baseline zu implementieren, entnehmen wir aus den Datensätzen die häufigsten Wörter, die jeweils in Tweets mit Label "positive", "negative", "neutral" zu finden sind. Für einen zu klassifizierenden Tweet zählen wir die Aufkommen dieser Wörter und weisen das Label zu, das die meisten dieser Wörter enthält.

# %% [markdown]
# Zuerst erstellen wir das Dictionary, mit dem wir den Classifier trainieren.

# %%
import random
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

        
    
# Extrahiere alle positiven/ negativen/ neutralen Trainings-Tweets und füge diese in ein Dictionary ein, dass für einen 
# Bayes-Klassifizierer geeignet ist

positive_tweets = [[content] for [tag, sentiment, content] in train if sentiment == "positive"]
positive_tweets = [[word for sentence in sublist for word in sentence.split()] for sublist in positive_tweets]

negative_tweets = [[content] for [tag, sentiment, content] in train if sentiment == "negative"]
negative_tweets = [[word for sentence in sublist for word in sentence.split()] for sublist in negative_tweets]

neutral_tweets = [[content] for [tag, sentiment, content] in train if sentiment == "neutral"]
neutral_tweets = [[word for sentence in sublist for word in sentence.split()] for sublist in neutral_tweets]

positive_tokens_for_model = get_tweets_for_model(positive_tweets)
negative_tokens_for_model = get_tweets_for_model(negative_tweets)
neutral_tokens_for_model = get_tweets_for_model(neutral_tweets)



positive_dataset = [(tweet_dict, "positive") for tweet_dict in positive_tokens_for_model]
negative_dataset = [(tweet_dict, "negative") for tweet_dict in negative_tokens_for_model]
neutral_dataset = [(tweet_dict, "neutral") for tweet_dict in neutral_tokens_for_model]

train_dataset = positive_dataset + negative_dataset + neutral_dataset

# %% [markdown]
# Wir müssen ebenfalls das Test-Dataset in ein dictionary-Format bringen, das für einen Naiven Bayes-Klassifizierer geeignet ist. Dies ist äquivalent zu dem Trainings-Dataset

# %%
# Extrahiere alle positiven/ negativen/ neutralen Test-Tweets und füge diese in ein Dictionary ein, dass für einen 
# Bayes-Klassifizierer geeignet ist
positive_test_tweets = [[content] for [tag, sentiment, content] in test if sentiment == "positive"]
positive_test_tweets = [[word for sentence in sublist for word in sentence.split()] for sublist in positive_test_tweets]

negative_test_tweets = [[content] for [tag, sentiment, content] in test if sentiment == "negative"]
negative_test_tweets = [[word for sentence in sublist for word in sentence.split()] for sublist in negative_test_tweets]

neutral_test_tweets = [[content] for [tag, sentiment, content] in test if sentiment == "neutral"]
neutral_test_tweets = [[word for sentence in sublist for word in sentence.split()] for sublist in neutral_test_tweets]

positive_test_tokens_for_model = get_tweets_for_model(positive_test_tweets)
negative_test_tokens_for_model = get_tweets_for_model(negative_test_tweets)
neutral_test_tokens_for_model = get_tweets_for_model(neutral_test_tweets)



positive_test_dataset = [(tweet_dict, "positive") for tweet_dict in positive_test_tokens_for_model]
negative_test_dataset = [(tweet_dict, "negative") for tweet_dict in negative_test_tokens_for_model]
neutral_test_dataset = [(tweet_dict, "neutral") for tweet_dict in neutral_test_tokens_for_model]

test_dataset = positive_test_dataset + negative_test_dataset + neutral_test_dataset

# %% [markdown]
# Anschließend können wir einen einen Naiven Bayes-Klassifizierer trainieren und testen:

# %%
from nltk import classify
from nltk import NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_dataset)

accuracy = classify.accuracy(classifier, test_dataset)
print("Accuracy is:", accuracy)

print(classifier.show_most_informative_features(30))
# Out:
# Accuracy is: 0.5841556244713842
# Most Informative Features
#                     luck = True           positi : neutra =     39.1 : 1.0
#                    excit = True           positi : neutra =     38.2 : 1.0
#                      sad = True           negati : neutra =     37.1 : 1.0
#                     fuck = True           negati : neutra =     35.7 : 1.0
#                    happi = True           positi : neutra =     30.0 : 1.0
#                    sorri = True           negati : neutra =     29.6 : 1.0
#                   injuri = True           negati : positi =     29.1 : 1.0
#                     amaz = True           positi : neutra =     28.5 : 1.0
#                   awesom = True           positi : neutra =     27.0 : 1.0
#                    thank = True           positi : neutra =     24.9 : 1.0
#                      fun = True           positi : neutra =     24.3 : 1.0
#                     suck = True           negati : neutra =     23.3 : 1.0
#                     cant = True           positi : neutra =     23.1 : 1.0
#                     fail = True           negati : positi =     22.5 : 1.0
#                      cri = True           negati : neutra =     22.0 : 1.0
#                    proud = True           positi : neutra =     21.4 : 1.0
#                    great = True           positi : neutra =     21.0 : 1.0
#                   anymor = True           negati : neutra =     19.9 : 1.0
#                  protest = True           negati : positi =     19.1 : 1.0
#                    enjoy = True           positi : neutra =     17.5 : 1.0
#                     hate = True           negati : neutra =     16.9 : 1.0
#                     cool = True           positi : neutra =     16.7 : 1.0
#                    delay = True           negati : positi =     15.8 : 1.0
#                  demitra = True           negati : positi =     15.8 : 1.0
#                    pavol = True           negati : positi =     15.8 : 1.0
#                    ignor = True           negati : neutra =     15.7 : 1.0
#                  ridicul = True           negati : neutra =     15.7 : 1.0
#                   spirit = True           negati : positi =     14.1 : 1.0
#                 breakout = True           negati : neutra =     13.6 : 1.0
#                embarrass = True           negati : neutra =     13.6 : 1.0
# None

# %% [markdown]
# Der Naive-Bayes-Klassifizierer resultiert in einer Accurracy von ~59%. Wir überprüfen folgenderweise, ob Wörter, die oft ausschließlich in positiven/ negativen/ neutralen Tweets auch hilfreich für den obigen Bayes-Klassifizierer sind folgendermaßen:
#
# - Für alle positiven/negativen/ neutralen Tweets, sammle alle Wörter die in derartigen Tweets vorkommen
# - Stopwörter und Punktuation (mit Ausnahme von Smileys) ist nicht aussagekräftig und wird somit entfernt
# - Zähle dann mithilfe von FreqDist die häufigsten positiven, negativen, und neutralen Wörter
# - Für alle positiven/ negativen/ neutralen Wortmengen, betrachte nicht diejenigen, die auch in den jeweilig anderen Wortmengen auftreten
# - Die übrigbleibenden Wortmengen werden dann mit den hilfreichesten Features des Bayes-Klassifizierer verglichen.

# %%
positive_words = [content for [tag, sentiment, content] in train if sentiment == "positive"]
negative_words = [content for [tag, sentiment, content] in train if sentiment == "negative"]
neutral_words = [content for [tag, sentiment, content] in train if sentiment == "neutral"]

smiley_regex = re.compile(r'(:\)|:-\)|:\(|:-\(|;\)|;-\)|:\D|:-\D|<3)')

smileys = set()

for smiley in smiley_regex.findall(' '.join(map(chr, range(128)))):  
    smileys.add(smiley)

def remove_stopwords_and_punctuation(text_list):
    stop_words = set(stopwords.words('english'))
    punctuation = set(string.punctuation) - smileys
    
    filtered_text_list = []
    for text in text_list:
        words = nltk.word_tokenize(text)
        filtered_words = [word.lower() for word in words if (word.lower() not in stop_words and word.lower() not in punctuation)]
        filtered_text_list.append(" ".join(filtered_words))
    return filtered_text_list


positive_words = " ".join(remove_stopwords_and_punctuation(positive_words)).split()
negative_words = " ".join(remove_stopwords_and_punctuation(negative_words)).split()
neutral_words = " ".join(remove_stopwords_and_punctuation(neutral_words)).split()

fdist_positive = FreqDist(positive_words)
fdist_negative = FreqDist(negative_words)
fdist_neutral = FreqDist(neutral_words)

common_positive_words = set([item[0] for item in fdist_positive.most_common(400)])
common_negative_words = set([item[0] for item in fdist_negative.most_common(400)])
common_neutral_words = set([item[0] for item in fdist_neutral.most_common(400)])

common_positive_words_ = set(common_positive_words) -  (set(common_negative_words) | set(common_neutral_words))
common_negative_words_ = set(common_negative_words) - (set(common_positive_words) | set (common_neutral_words))
common_neutral_words_ = set(common_neutral_words) - (set(common_positive_words) | set (common_negative_words))

most_informative = [word for [word, contains] in classifier.most_informative_features(200)]
print("- Frequente positive Wörter, die auch informativ sind:  \n     {}".format(common_positive_words_.intersection(most_informative)))
print("- Frequente negative Wörter, die auch informativ sind:  \n     {}".format(common_negative_words_.intersection(most_informative)))
print("- Frequente neutrale Wörter, die auch informativ sind:  \n     {}".format(common_neutral_words_.intersection(most_informative)))
# Out:
# - Frequente positive Wörter, die auch informativ sind:
#      {'brilliant', 'proud', 'enjoy', 'excit', 'luck', 'favorit', 'sweet', 'perfect', 'yay', 'happi', 'nice', 'funni', 'thank', 'awesom', 'cool', 'fun', 'amaz'}
# - Frequente negative Wörter, die auch informativ sind:
#      {'pavol', 'tire', 'protest', 'dont', 'voic', 'rider', 'anymor', 'trayvon', 'sad', 'suck', 'sorri', 'injuri', 'bitch', 'net', 'wrong', 'ghost', 'cri', 'cancel', 'warn', 'crash', 'smh', 'hell', 'dead', 'fail', 'sick', 'piss', 'hate', 'worst', 'delay', 'wont', 'loss', 'demitra', 'die', 'kinda', 'damn'}
# - Frequente neutrale Wörter, die auch informativ sind:
#      {'begin', 'intern', 'trial'}

# %% [markdown]
# Das Ergebnis für positive bzw. negative Tweets ist nicht überraschend, da dies zumeist sehr aussagekräftige Word-features sind. Überraschend ist lediglich die Menge der frequenten und informativen negativen Wörter im Vergleich zu der Menge der frequenten und informativen positiven Wörtern, da es um einiges mehr derartiger negativer Wörter gibt, als positiver.
#
# Die frequenten und informativen neutralen Wörter sind nicht überraschend, da neutrale Tweets meist weniger aussagekräftige Features (im Vgl. mit positiven und negativen) beinhalten.

# %% [markdown]
# Anstatt den Bayes-Klassifizierer direkt auf den Train-Datensatz zu trainieren, können wir auch einen feature-Extraktor verwenden, der die nach obiger Methode häufigsten Wörter in positiven/ negativen/ neutralen Tweets extrahiert.

# %%
common_positive_words_ = [word for word in common_positive_words_]    
common_negative_words_ = [word for word in common_negative_words_]
common_neutral_words_ = [word for word in common_negative_words_]

all_words = common_positive_words_ + common_negative_words_ + common_neutral_words_ 

def extract_features(document):    
    document_words = set(document)
    features = {}
    word_features = all_words
    for word in word_features:
        features[word] = (word in document_words)
    return features

documents = [(content.split(), sentiment) for [tag, sentiment, content] in train]

labeled_features = [(extract_features(doc), category) for (doc, category) in documents]

classifier2 = classifier.train(labeled_features)

accuracy2 = nltk.classify.accuracy(classifier2, test_dataset)

print(accuracy2)

print(classifier2.show_most_informative_features(30))
# Out:
# 0.558782069354384
# Most Informative Features
#                     luck = True           positi : neutra =     39.1 : 1.0
#                    excit = True           positi : neutra =     38.2 : 1.0
#                      sad = True           negati : neutra =     37.1 : 1.0
#                    happi = True           positi : neutra =     30.0 : 1.0
#                    sorri = True           negati : neutra =     29.6 : 1.0
#                   injuri = True           negati : positi =     29.1 : 1.0
#                     amaz = True           positi : neutra =     28.5 : 1.0
#                   awesom = True           positi : neutra =     27.0 : 1.0
#                    thank = True           positi : neutra =     24.9 : 1.0
#                      fun = True           positi : neutra =     24.3 : 1.0
#                     suck = True           negati : neutra =     23.3 : 1.0
#                     fail = True           negati : positi =     22.5 : 1.0
#                      cri = True           negati : neutra =     22.0 : 1.0
#                    proud = True           positi : neutra =     21.4 : 1.0
#                   anymor = True           negati : neutra =     19.9 : 1.0
#                  protest = True           negati : positi =     19.1 : 1.0
#                    enjoy = True           positi : neutra =     17.5 : 1.0
#                     hate = True           negati : neutra =     16.9 : 1.0
#                     cool = True           positi : neutra =     16.7 : 1.0
#                    delay = True           negati : positi =     15.8 : 1.0
#                  demitra = True           negati : positi =     15.8 : 1.0
#                    pavol = True           negati : positi =     15.8 : 1.0
#                     damn = True           negati : neutra =     13.3 : 1.0
#                   cancel = True           negati : positi =     13.0 : 1.0
#                    worst = True           negati : positi =     12.5 : 1.0
#                    funni = True           positi : neutra =     11.8 : 1.0
#                    rider = True           negati : positi =     11.5 : 1.0
#                  favorit = True           positi : neutra =     11.0 : 1.0
#                brilliant = True           positi : neutra =     10.8 : 1.0
#                     nice = True           positi : neutra =     10.7 : 1.0
# None

# %% [markdown]
# Die Nützlichkeit von POS-Tagging kann mithilfe des nltk-Unigram Taggers untersucht werden. Dieser wird auf dem brown-dataset trainiert.

# %%
from nltk import UnigramTagger
from nltk.corpus import brown

brown_train = brown.tagged_sents()
ut = UnigramTagger(brown_train)

# %% [markdown]
# Dieser Unigram-Tagger kann verbessert werden, indem wir für unschlüssige Tags mithilfe dem Suffix (oder dem Auftreten von Nummern) erweitert taggen. Ebenfalls ändern wir das output von einem (word, tag)-Tuple zu einem word-tag String für Einfachkeit bei der folgenden Konvertierung in ein geeignetes Dictionary.

# %%
def utplus (sent) :
    out = [(word,"ZONK") for word in sent]   
    
    out = ut.tag(sent)   
    for i in range(len(out)):
        if out[i][1] == None:            
            #replace all None tags which contain a number as NUM:
            if(bool(re.search('1|2|3|4|5|6|7|8|9|0|one|two|three|four|five|six|seven|eight|nine|ten', out[i][0].lower()))):
                out[i] = (out[i][0], 'NUM')              
            #replace all None tags which have a capital Letter as the first letter with NOUN:
            if(out[i][0][0].isupper()):
                out[i] = (out[i][0], 'NN')
            #replace all None tags which have -ly | -able suffix with ADV:                
            if(out[i][0].endswith(('ly', 'able'))):
                out[i] = (out[i][0], 'ADV')
            #replace all None tags which have -ally | -ous | -est | -ial |-ic with ADJ:
            if(out[i][0].endswith(('ally', 'ous', 'est', 'ial', 'ate', 'ic', 'al', 'ent'))):
                out[i] = (out[i][0], 'ADJ')
            #replace all None tags which have -ies | -cy | -age | -'s |-ing | -ion |s |-ity |-ment | -ty suffix with NN:
            if(out[i][0].endswith(('ies', 'cy', 'age', '\'s', 'ing', 'ion', 's', 'ity', 'ment', 'ty', 'ance'))):
                out[i] = (out[i][0], 'NN')
            #replace all None tags which have -ed suffix with VBD
            if(out[i][0].endswith(('ed'))):
                out[i] = (out[i][0], 'VBD')  
            #replace all None tags which have -ing suffix with VBG
            if(out[i][0].endswith(('ing'))):
                out[i] = (out[i][0], 'VBG')                
            else:
                out[i] = (out[i][0], 'NN')
                
    for (word, tag) in out:
        if(tag == None):
            print(word)
    out = [word.lower() + "-" + tag for (word, tag) in out]        
    print(out)
    return out

# %% [markdown]
# Wir wiederholen jetzt obigen Code unter Betrachtung der POS-Tags, allerdings ohne Lemmatisierung.

# %%
dev_ = [[tag, sentiment, utplus(remove_words(decode_unicode_escapes(content)).split())] for [tag, sentiment, content] in dev_]

test_ = [[tag, sentiment, utplus(remove_words(decode_unicode_escapes(content)).split())] for [tag, sentiment, content] in test_]

train_ = [[tag, sentiment, utplus(remove_words(decode_unicode_escapes(content)).split())] for [tag, sentiment, content] in train_]
# Out:
# ['won-NN', 'the-AT', 'match-VB', '.-.', 'plus,-NN', 'tomorrow-NR', 'is-BEZ', 'a-AT', 'very-QL', 'busy-JJ', 'day,-NN', 'with-IN', 'awareness-NN', 'day’s-NN', 'and-CC', 'debates.-NN', 'gulp.-NN', 'debates...-NN']
# ['some-DTI', 'areas-NNS', 'of-IN', 'new-JJ-TL', 'england-NP', 'could-MD', 'see-VB', 'the-AT', 'first-OD', 'flakes-NNS', 'of-IN', 'the-AT', 'season-NN', 'tuesday.-NN']
# ['2nd-OD', 'worst-JJT', 'qb.-NN', 'definitely-NN', 'tony-NP', 'romo.-NN', 'the-AT', 'man-NN', 'who-WPS', 'likes-VBZ', 'to-TO', 'share-NN', 'the-AT', 'ball-NN', 'with-IN', 'everyone.-NN', 'including-IN', 'the-AT', 'other-AP', 'team.-NN']
# ['washington-NP', '--IN', 'us-NN', 'president-NN-TL', 'barack-NN', 'obama-NN', 'vowed-VBD', 'wednesday-NR', 'as-CS', 'he-PPS', 'visited-VBD', 'storm-ravaged-NN', 'new-JJ-TL', 'jersey-NP-TL', 'shore-NN', 'to...-NN']
# ['did-DOD', 'y𠆚ll-NN', 'hear-VB', 'what-WDT', 'tony-NP', 'romo-NN', 'dressed-VBN', 'up-RP', 'as-CS', 'for-IN', 'halloween?-NN', 'a-AT', 'giants-NNS-TL', 'quaterback!-NN', 'cause-NN', 'that’s-NN', 'all-ABN', 'he-PPS', 'could-MD', 'throw-VB', 'to-TO', 'sunday-NN', 'night.-NN']
# ['tim-NP', 'tebow-NN', 'may-MD', 'be-BE', 'availible-NN', '!-.', 'wow-UH', 'jerry-NP', ',-,', 'what-WDT', 'the-AT', 'heck-NN', 'you-PPSS', 'waiting-VBG', 'for-IN', '!-.']
# ['aga-NN', 'tayo-NN', 'tomorrow-NR', 'ah.-NN', ':)-NN', 'good-JJ', 'night,-NN', 'ces.-NN', 'love-NN-TL', 'you!-NN', '>:d<-NN']
# ['tina-NN', 'fey-NN', '&-CC-TL', 'amy-NP', 'poehler-NN', 'are-BER', 'hosting-VBG', 'the-AT', 'golden-JJ-TL', 'globe-NN-TL', 'awards-NNS', 'on-IN', 'january-NP', '13.-NN', 'what-WDT', 'do-DO', 'you-PPSS', 'think?-NN']
# ['lunch-NN', 'from-IN', 'my-PP$', 'new-JJ', 'lil-NP', 'spot-NN', '...the-NN', 'cotton-NN', 'bowl-NN', '....pretty-NN', 'good-JJ', 'be-BE', 'going-VBG', 'back#-NN']
# ['snc-NN', 'halloween-NP', 'pr.-NN', 'pumped.-NN', 'let’s-NN', 'work-NN', 'it-PPS', 'for-IN', 'sunday....packers-NN', 'vs....who-NN', 'knows-VBZ', 'or-CC', 'caresn.-NN']
# ['i’m-NN', 'sorry,-NN', 'i-PPSS', 'heart-NN-TL', 'paris-NP', 'is-BEZ', 'no-AT', 'longer-RBR', 'available-JJ', 'at-IN', 'the-AT', 'rockwell-NN', 'branch!-NN', 'you-PPSS', 'may-MD', 'call-VB', '8587000-NN', 'to-TO', 'get-VB', 'a-AT', 'copy-NN', 'transferred!-NN', ':)-NN']
# ['manchester-NP-TL', 'united-VBN-TL', 'will-MD', 'try-VB', 'to-TO', 'return-NN', 'to-TO', 'winning-VBG', 'ways-NNS', 'when-WRB', 'they-PPSS', 'face-NN', 'arsenal-NN', 'in-IN', 'the-AT', 'premier-NN-TL', 'league-NN-TL', 'at-IN', 'old-JJ-TL', 'trafford-NN', 'on-IN', 'saturday.-NN']
# ['going-VBG', 'to-TO', 'a-AT', 'bulls-NNS', 'game-NN', 'with-IN', 'aaliyah-NN', '&-CC-TL', 'hope-NN', 'next-AP', 'thursday-NR']
# ['any-DTI', 'toon-NN', 'fans-NN', 'with-IN', 'a-AT', 'spare-JJ', 'ticket-NN', 'for-IN', 'anfield-NN', 'on-IN', 'sunday?willing-VBG', 'to-TO', 'pay-VB', 'extra-JJ']
# ['louis-NP', 'inspired-VBN', 'outfit-NN', 'on-IN', 'monday-NR', 'and-CC', 'zayn-NN', 'inspired-VBN', 'outfit-NN', 'today..4/5-NN', 'done-VBN', 'just-RB', 'need-VB', 'harry-NP', ':)-NN']
# ['going-VBG', 'to-TO', 'bed-NN', 'now...rose-NN', 'parade-NN', 'then-RB', 'game-NN', 'tomorrow-NR']
# ['oh-UH', 'cause-NN', 'my-PP$', 'friend-NN', 'got-VBD', 'something-PN', 'from-IN', 'china-NN', 'and-CC', 'they-PPSS', 'said-VBD', 'it-PPS', 'will-MD', 'take-VB', 'at-IN', 'least-AP', '6-CD', 'to-TO', '8-CD', 'weeks-NNS', 'and-CC', 'it-PPS', 'came-VBD', 'in-IN', 'the-AT', '2nd-OD', 'week-NN', ':p-NN']
# ['"i-NN', 'love-NN', 'the-AT', 'banner-NN', 'that-CS', 'was-BEDZ', 'unfurled-VBN', 'in-IN', 'the-AT', 'united-VBN-TL', 'end-NN', 'last-AP', 'night.-NN', 'it-PPS', 'read:-NN', '\\""chelsea-NN', '--IN', 'standing-VBG', 'up-RP', 'against-IN', 'racism-NN', 'since-CS', 'sunday\\"""-NN']
# ['chris-NP', 'bosh-NN', 'may-MD', 'be-BE', 'ugly.-NN', 'but-CC', 'he-PPS', 'has-HVZ', 'a-AT', 'gorgeous-JJ', 'wife-NN', 'and-CC', 'adorbs-NN', 'baby.-NN', 'i-PPSS', 'want-VB', 'to-TO', 'be-BE', 'happy-JJ', 'like-CS', 'them-PPO', 'one-CD']
# ['is-BEZ', 'this-DT', 'one-CD', 'of-IN', 'your-PP$', 'little-AP', 'jokes-NNS', 'like-CS', 'elvis-NP', 'playing-VBG', 'at-IN', 'the-AT', 'marquee-NN', 'next-AP', 'tuesday?-NN']
# ['"gary-NN', 'ablett-NN', 'wins-VBZ', 'the-AT', 'aflpa-NN', 'mvp-NN', 'for-IN', 'the-AT', '4th-OD', 'time-NN', 'in-IN', 'his-PP$', 'career.-NN', 'he-PPS', 'should-MD', 'have-HV', 'started-VBD', 'his-PP$', 'speech-NN', 'with--NN', '\\""yeah,-NN', 'i𠆝...-NN']
# ['gold-JJ-TL', 'edges-NNS', 'down-RP', 'ahead-RB', 'of-IN', 'us-NN', 'jobs-NNS', 'data:-NN', 'singapore-NN', '(reuters)-NN', '--IN', 'gold-JJ-TL', 'edged-VBD', 'lower-JJR', 'on-IN', 'friday,-NN', 'with-IN', 'investors-NNS', 'waiting-VBG', 'for...-NN']
# ['.:-NN', 'another-DT', 'close-range-NN', 'iu-NN', 'shot-NN', 'goes-VBZ', 'high.-NN', 'kyle-NN', 'schickel-NN', 'checks-NNS', 'in-IN', 'for-IN', 'missimo.-NN', 'kyle-NN', 'missed-VBN', 'the-AT', 'wisconsin-NP', 'game-NN', 'last-AP', 'sunday.-NN']
# ['lana-FW-NN-TL', 'del-NP', 'rey-NP', 'at-IN', 'hammersmith-NN', 'apollo-NP-TL', 'in-IN', 'may...-NN', 'very-QL', 'badly-RB', 'want-VB', 'tickets-NNS']
# ['shaw-NP', 'wouldn’t-NN', 'let-VB', 'luck-NN', 'throw-VB', 'late-JJ', 'in-IN', 'the-AT', 'fiesta-NN', 'bowl,-NN', 'but-CC', 'he’s-NN', 'fine-JJ', 'with-IN', 'nunes-NP', 'throwing-VBG', 'a-AT', 'fade-NN', 'route-NN', 'on-IN', '4th-OD', 'and-CC', '4-CD', 'w/-NN', '1:50-NN', 'left.-NN']
# ['monday-NR', 'before-CS', 'i-PPSS', 'leave-VB', 'singapore,-NN', 'i-PPSS', 'am-BEM', 'going-VBG', 'to-TO', 'post-NN', 'something-PN', 'that-CS', 'might-MD', 'be-BE', 'offensive.-NN']
# ['abc-NP', 'has-HVZ', ',-,', 'and-CC', 'the-AT', 'country-NN-TL', 'music-NN-TL', 'awards,-NN', 'they-PPSS', 'may-MD', 'still-RB', 'have-HV', 'a-AT', 'little-AP', 'credibility-NN', 'come-VB', 'wednesday.-NN']
# ['here-RB', 'in-IN', 'the-AT', 'philippines,-NN', 'its-PP$', 'november-NP', '2-CD', 'and-CC', 'i-PPSS', 'was-BEDZ', 'like-CS', 'where’s-NN', 'my-PP$', 'phone?!-NN', 'what-WDT', 'is-BEZ', 'the-AT', 'time-NN', 'in-IN', 'london?!-NN']
# ['tonight-NR', 'dr.-NN-TL', 'terrie-NN', 'hale-NP', 'scheckelhoff-NN', 'will-MD', 'be-BE', 'formally-RB', 'installed-VBN', 'as-CS', 'the-AT', '11th-OD', 'head-NN-TL', 'of-IN', 'school.-NN', 'welcome-UH-TL', 'to-TO', 'the-AT', 'saints-NNS-TL', 'family-NN', '!-.']
# ['man,-NN', 'bye.-NN', 'i-PPSS', 'gotta-VBN+TO', 'work-NN', 'all-ABN', 'day-NN', 'and-CC', 'drive-NN', 'to-TO', 'houston-NP', 'tomorrow.-NN']
# ['won’t-NN', 'get-VB', 'emojis-NN', 'till-CS', 'tomorrow-NR', 'beeeotch!-NN', 'when-WRB', 'is-BEZ', 'your-PP$', 'grandma-NN', 'going-VBG', 'back-RB', 'to-TO', 'brazil?-NN', 'i-NN', 'wanna-VB+TO', 'see-VB', 'your-PP$', 'fam-NN', 'before-CS', 'they-PPSS', 'leave!-NN']
# ['’love-cheat’-NN', 'daniel-NP', 'radcliffe-NN', 'splits-VBZ', 'with-IN', 'girlfriend-NN', 'rosie-NP', 'coker:-NN', 'london,-NN', 'oct-NN', '19:-NN', 'daniel-NP', 'radcliffe-NN', 'has-HVZ', 'split-VBN', 'wit...-NN']
# ['he’s-NN', 'a-AT', 'true-JJ', 'niners-NN', 'fan,-NN', 'he-PPS', 'brought-VBD', 'it-PPS', 'up-RP', 'in-IN', 'a-AT', 'interview-NN', 'during-IN', 'his-PP$', '2nd-OD', 'season.-NN', ':d-NN']
# ['patriots-NN', 'extend-VB', 'lead,-NN', 'cruise-NP', 'into-IN', '4th-OD', 'with-IN', '38-7-CD', 'lead-VB', '--IN', 'pats-NN', 'pulpit:-NN', 'the-AT', 'patriots-NN', 'extended-VBN', 'their-PP$', 'lead-VB', 'in-IN', 'the-AT', '3rd-OD', '...-NN']
# ['yeah-RB', 'i-PPSS', 'think-VB', 'so.-NN', 'we-PPSS', 'saw-VBD', 'suarez-NN', 'score-NN', 'up-RP', 'near-IN', 'us-PPO', 'and-CC', 'we-PPSS', 'played-VBD', 'pretty-QL', 'well-RB', '2nd-OD', 'half-ABN', 'so-QL', 'it-PPS', 'wasn’t-NN', 'so-QL', 'bad.-NN', 'probably-RB', 'should’ve-NN', 'had-HVD', 'et-NN']
# ['i-PPSS', 'may-MD', 'exit-NN', 'off-RP', 'twitter-NN', 'and-CC', 'fb-NN', 'and-CC', 'thug-NN', 'with-IN', 'instagram-NN', 'btw-NN', 'its-PP$', 'blonde_lifestyle:insta-NN']
# ['indiana-NP', '1,-NN', 'northwestern-JJ-TL', '0,-NN', 'end-NN', 'first-OD', 'half,-NN', 'men’s-NN', 'soccer.-NN', 'eriq-NN', 'zavaleta’s-NN', '16th-OD', 'goal-NN', 'the-AT', 'difference.-NN', 'iu-NN', 'dominating-VBG', 'play.-NN']
# ['"vh1’s-NN', '\\""mob-NN', 'wives\\""-NN', 'celebrate-NN', 'the-AT', '20th-OD', 'anniversary-NN-TL', 'of-IN', 'the-AT', 'clothing-VBG', 'line-NN-TL', 'in-IN', 'new-JJ-TL', 'york-NP-TL', 'city-NN-TL', '--IN', '"-NN']
# ['pretty-QL', 'little-JJ-TL', 'liars-NN', 'was-BEDZ', 'the-AT', 'shit-NN', '!-.', 'i-PPSS', 'can’t-NN', 'wait-VB', 'til-NN', 'tomorrow-NR', '!-.', 'i-PPSS', 'wanna-VB+TO', 'see-VB', 'who-WPS', 'all-ABN', 'innocent-JJ', '&-CC-TL', 'who-WPS', 'got-VBD', 'something-PN', 'to-TO', 'do-DO', 'with-IN', 'allison-NP', 'dying-VBG', '!-.']
# ['texas-NP', 'and-CC', 'baylor-NP', 'both-ABX', 'looked-VBD', 'awesome-JJ', 'last-AP', 'night.-NN', 'we-PPSS', 'are-BER', 'heading-NN', 'to-TO', 'the-AT', 'games-NNS', 'tomorrow-NR', 'night.i-NN', 'say-VB', 'final-JJ', 'is-BEZ', 'texas/baylor-NN']
# ['if-CS', 'you-PPSS', 'are-BER', 'in-IN', 'vancouver-NN', 'this-DT', 'weekend,-NN', 'check-VB', 'out-RP', 'on-IN', 'sat.-NN', 'at-IN', '20:00-NN', '@-NN', 'the-AT', 'commo-NN', 'in-IN', 'vancouver,-NN', 'bc-NN']
# ['great-NN', 'game-NN', 'girls!!-NN', 'on-IN', 'to-TO', 'districts-NNS', 'monday-NR', 'at-IN', 'fox!!-NN', 'thanks-NNS', 'to-TO', 'the-AT', 'fans-NNS', 'for-IN', 'coming-VBG', 'out-RP', ':)-NN']
# ['jesiah-NN', 'of-IN', 'course-NN', 'can’t-NN', 'fall-NN', 'asleep.-NN', 'so-RB', 'since-CS', 'he’s-NN', 'off-RP', 'school-NN', 'tomorrow,-NN', 'he’s-NN', 'cuddled-NN', 'up-RP', 'with-IN', 'mama-NN', 'watching-VBG', 'wizards-NN', 'of-IN', 'waverly-NN', 'place<3-NN']
# ['it-PPS', 'says-VBZ', 'on-IN', 'wiki-NN', 'that-CS', 'the-AT', 'ep-NN', 'will-MD', 'now-RB', 'air-NN', 'on-IN', 'the-AT', '13th,-NN', 'no-AT', 'links-NNS', 'at-IN', 'the-AT', 'moment-NN', 'for-IN', 'it.-NN']
# ['cardinal-NN-TL', 'men-NNS', 'take-VB', '4th-OD', 'in-IN', 'cypress-NN-TL', 'point-NN-TL', 'tournament:-NN', 'a-AT', 'good-JJ', 'host-NN', 'never-RB', 'outshines-NN', 'their-PP$', 'guests,-NN', 'but-CC', 'the-AT', 'stanford-NP-TL', 'me...-NN']
# ['who’s-NN', 'going-VBG', 'to-TO', 'concords-NN', 'football-NN', 'game-NN', 'this-DT', 'saturday?-NN']
# ['17,-NN', 'plays-VBZ', 'softball,-NN', 'loves-VBZ', 'the-AT', 'lakers,-NN', 'she’s-NN', 'a-AT', 'la-NN', 'girl,-NN', 'junior,-NN', 'birthday-NN', 'september,-NN', '15th-OD', '&-CC-TL', 'she-PPS', 'loves-VBZ', 'her-PP$', 'black-JJ', 'boys!-NN']
# ['"so-NN', 'friday-NR', 'at-IN', 'onyx-NN', 'there-EX', 'was-BEDZ', 'a-AT', 'bachelor-NN', 'party-NN', '&-CC-TL', 'the-AT', 'best-JJT', 'man-NN', 'tells-VBZ', 'the-AT', 'bachelor,-NN', '\\""you-NN', 'getting-VBG', 'married-VBN', 'tomorrow!\\""-NN', 'the-AT', 'bachelor-NN', 'says..."-NN']
# ['waking-VBG', 'up-RP', 'to-TO', 'a-AT', 'niners-NN', 'win,-NN', 'makes-VBZ', 'tuesday-NR', 'get-VB', 'off-RP', 'to-TO', 'a-AT', 'great-JJ', 'start!-NN', '21-3-NN', 'over-IN', 'the-AT', 'cards-NNS', 'and-CC', '2-CD', 'games-NNS', 'clear-JJ', 'in-IN', 'the-AT', 'nfc-NN', 'west.-NN']
# ['contest-NN-TL', 'tomorrow!-NN', 'i-PPSS', 'will-MD', 'post-NN', 'a-AT', 'local-JJ', 'tucson-NP', 'property-NN', 'that-CS', 'is-BEZ', 'currently-RB', 'active-JJ', 'in-IN', 'the-AT', 'tucson-NP', 'mls.-NN', 'the-AT', 'first-OD', 'person...-NN']
# ['if-CS', 'it’s-NN', 'the-AT', 'iowa-NP', 'vs.-IN', 'indiana-NP', 'game,-NN', 'we-PPSS', 'may-MD', 'be-BE', 'the-AT', 'only-RB', 'two-CD', 'there!-NN']
# ['nooooooo-NN', 'this-DT', 'sunday-NR', 'is-BEZ', 'the-AT', 'last-AP', 'episode-NN', 'of-IN', 'downton-NN', 'abbey.-NN', ':(-NN', 'there’s-NN', 'a-AT', 'christmas-NP', 'special-JJ', 'coming-VBG', 'but-CC', 'that’s-NN', 'ages-NN', 'away.-NN']
# ['im-NN', 'so-QL', 'excited-VBN', 'even-RB', 'though-CS', 'i-NN', 'wont-JJ', 'see-VB', 'you-PPSS', 'til-NN', 'novemeber-NN', '5th.-NN', 'oiershdjkfwle-NN', 'good-NN', 'luck-NN', 'tonight,-NN', 'kidrauhl!-NN']
# ['i-PPSS', 'believe-VB', 'the-AT', 'snobish-NN', 'mainstream-NN', 'media,-NN', 'abc,-NN', 'cbs,nbc,-NN', 'cnn,-NN', 'msnbc-NN', 'may-MD', 'get-VB', 'their-PP$', 'comeupance-NN', 'this-DT', 'election.-NN', 'people-NNS', 'r-NN', 'sick-JJ', 'of-IN', 'their-PP$', 'bias!-NN']
# ['if-CS', 'you-PPSS', 'didnt-NN', 'see-VB', 'it-PPS', 'already-RB', 'heres-NN', 'my-PP$', 'halloween-NP', 'effort-NN', 'from-IN', 'saturday-NR', '--IN', 'david-NP', 'bowie-NP-HL', 'frm-NN', 'the-AT', 'labyrinth-NN', 'as-CS', 'a-AT', 'vamp!-NN']
# ['well-UH', 'if-CS', 'no-AT', 'ones-NNS', 'going-VBG', 'to-TO', 'school-NN', 'tomorrow-NR', 'then-RB', 'i-PPSS', 'guess-VB', 'i-PPSS', 'won’t-NN', 'go-VB', ':p-NN']
# ['tom-NP', 'brady-NP', 'wins-VBZ', 'afc-NN', 'offensive-JJ', 'player-NN', 'of-IN', 'the-AT', 'week-NN', 'for-IN', '22nd-OD', 'time-NN', '(via-NN', ')-)']
# ['watching-VBG', 'contraband-NN', 'on-IN', 'the-AT', 'pvr-NN', '&-CC-TL', 'it’s-NN', 'too-QL', 'frigging-VBG', 'predictable-JJ', 'to-TO', 'continue-VB', 'watching.-NN', 'gonna-VBG+TO', 'go-VB', 'wash-NN', 'my-PP$', 'hair.-NN']
# ['i𠆝-NN', 'be-BE', 'pretty-QL', 'mad-JJ', 'if-CS', 'the-AT', 'packers-NPS', 'took-VBD', 'bernard-NP', 'in-IN', 'the-AT', '1st-NN', 'just-RB', 'bc,-NN', 'cooper/eifert-NN', 'would-MD', 'be-BE', 'better-JJR', 'imo.-NN']
# ['herald-NN-TL', 'sun:-NN', 'afl-NN', 'stars-NNS', 'make-VB', 'their-PP$', 'ufc-NN', '152-NN', 'picks:-NN', 'dane-NN', 'swan-NN-TL', 'and-CC', 'gary-NP', 'ablett-NN', 'give-VB', 'us-PPO', 'their-PP$', 'pick...-NN']
# ['very-QL', 'amazayn-NN', 'voice-NN', 'to-TO', 'the-AT', '1st-NN', 'verse-NN', 'man-NN', 'zayn-NN', 'malik!-NN', 'xx-NN']
# ['steal-NN', 'by-IN', 'chalmers,-NN', 'on-IN', 'the-AT', 'break-VB', 'away-RB', 'and-CC', 'is-BEZ', 'fouled-VBD', 'by-IN', 'garnett.-NN', 'that-DT', 'is-BEZ', 'his-PP$', '3rd-OD', 'foul-JJ', 'of-IN', 'this-DT', 'game.-NN']
# ['you-PPSS', 'out-RP', 'again-RB', 'on-IN', 'thursday-NR', 'for-IN', 'at-IN', 'chalmers??-NN']
# ['"free-NN', 'to-TO', 'watch!!!-NN', 'justified:-NN', '\\""justified\\""-NN', 'follows-VBZ', 'marshal-NN-TL', 'raylan-NN', 'givens,-NN', 'a-AT', 'modern-JJ', 'day-NN', '19th-OD', 'century-style-NN', 'lawman,-NN', 'w...-NN']
# ['come-VB', 'support-NN', 'the-AT', 'show/movement-NN', 'at-IN', 'park-NN-TL', 'dale-NN', 'high-JJ-TL', 'school-NN-TL', 'on-IN', 'oct-NN', '26th-OD', 'from-IN', '8-11-NN', 'w/-NN', 'aja,-NN', 'dreamteam,-NN', 'hqb,-NN', 'dsb-NN', '&-CC-TL', 'hib-NN']
# ['i-PPSS', 'admire-VB', 'the-AT', 'relationship-NN', 'u-NP', 'have-HV', 'with-IN', 'your-PP$', 'family.-NN', 'lol-NN', 'iron-NN', 'man’s-NN', 'a-AT', 'pretty-QL', 'suitable-JJ', 'costume.-NN', 'good-JJ', 'luck-NN', 'monday-NR', 'go-VB', 'saints!-NN']
# ['well-RB', 'i-NN', 'went-VBD', 'maths-NN', 'on-IN', 'mon,-NN', 'tues-NN', '+-NN', 'wed-VB', 'but-CC', 'cba-NN', 'now-RB', 'youu?-NN', '&nopee-NN', 'just-RB', 'town-NN', 'today-NR', 'and-CC', 'thats-NN', 'itt-NN', 'x_x-NN']
# ['lance-NN', 'just-RB', 'left,-NN', 'dinner-NN', 'with-IN', 'the-AT', 'fam-NN', 'was-BEDZ', 'great.-NN', 'managed-NN', 'to-TO', 'watch-VB', 'napoleon-NP', 'dynamite-NN', 'and-CC', 'the-AT', 'devil-NN-TL', 'inside.-NN', 'long-JJ-TL', 'story-NN', 'short:-NN', 'wonderful-JJ', 'sunday.-NN']
# []
# ['your-PP$', 'like-CS', 'jordan’s-NN', 'on-IN', 'a-AT', 'saturday-NR', 'i-PPSS', 'got-VBD', 'to-TO', 'have-HV', 'you-PPSS', 'and-CC', 'i-PPSS', 'cannot-MD*', 'wait.-NN', '.-.']
# ['but-CC', 'i-NN', 'wanna-VB+TO', 'wear-VB', 'my-PP$', 'concords-NN', 'tomorrow-NR', 'though-CS', 'but-CC', 'i-NN', 'don’t-NN', 'feel-VB', 'like-CS', 'it-PPS']
# ['gonna-VBG+TO', 'watch-VB', 'grey’s-NN', 'anatomy-NN', 'all-ABN', 'day-NN', 'today-NR', 'and-CC', 'tomorrow(:-NN']
# ['heey-NN', 'do-DO', 'you-PPSS', 'know-VB', 'anything-PN', 'about-IN', 'uva’s-NN', 'fallll-NN', 'fest-NN', 'loll-NN', 'they-PPSS', 'invited-VBN', 'me-PPO', 'so-QL', 'im-NN', 'going-VBG', 'this-DT', 'sat-VBD', 'but-CC', 'i-NN', 'really-RB', 'dont-NN', 'know-VB', 'what-WDT', 'it-PPS', 'is-BEZ', 'loll-NN']
# ['when-WRB', 'that-CS', 'sun-NN', 'is-BEZ', 'high-JJ', 'in-IN', 'that-CS', 'texas-NP', 'sky,-NN', 'i’ll-NN', 'be-BE', 'buckin-NN', 'it-PPS', 'to-TO', 'county-NN', 'fair.-NN', 'amarillo-NN', 'by-IN', 'morning.-NN', 'amarillo-NN', 'ill-JJ', 'be-BE', 'there...-NN']
# ['up-RP', '20-CD', 'points-NNS', 'in-IN', 'my-PP$', 'money-NN', 'league-NN', 'with-IN', 'vernon-NP', 'davis-NP', 'and-CC', 'l.-NP', 'fitz-NN', 'still-RB', 'to-TO', 'go-VB', 'tomorrow.-NN', 'thats-NN', 'what-WDT', 'i-PPSS', 'like-CS', 'to-TO', 'see-VB']
# ['deejaying-NN', 'this-DT', 'friday-NN', 'in-IN', 'the-NN', 'first-NN', 'chop-NN', 'it’s-NN', 'chris-NN', 'actual-JJ', 'smith-NN', 'with-IN', 'a-AT', 'smashing-VBG', 'mish-NN', 'mashing-VBG', 'of-IN', 'tunes-NN', 'from-IN', 'stoke...-NN']
# ['the-AT', 'rick-NN', 'santorum-NN', 'signing-VBG', 'that-CS', 'was-BEDZ', 'scheduled-VBN', 'for-IN', 'tomorrow-NR', 'at-IN', 'the-AT', 'books-NNS', 'a-AT', 'million-NN', 'in-IN', 'exton,-NN', 'pa-NN', 'has-HVZ', 'been-BEN', 'cancelled-NN', 'due-JJ', 'to-TO', 'the-AT', 'weather.-NN']
# ['just-RB', 'noticed-VBD', 'ricky-NN', 'gervais-NN', 'and-CC', 'stephen-NP', 'merchant’s-NN', 'life’s-NN', 'too-QL', 'short-NP', 'started-VBD', 'airing-VBG', 'on-IN', 'bbc-NN', 'entertainment.-NN', 'check-VB', 'it-PPS', 'out-RP', 'on-IN', 'sunday,-NN', '20:30.-NN']
# ['lol-NN', 'yep-NN', 'looks-VBZ', 'like-CS', 'it!-NN', 'was-BEDZ', 'after-IN', 'el-NP', 'clasico-NN', 'on-IN', 'sunday.-NN', 'i-PPSS', 'didn’t-NN', 'like-CS', 'her-PP$', 'lol-NN', 'and-CC', 'this-DT', 'doesn’t-NN', 'look-VB', 'serious-JJ', 'so-QL', 'i’m-NN', 'cool-JJ', 'lol-NN']
# ['as-CS', 'usual-JJ', 'no.-NN-HL', 'you-PPSS', 'can-MD', 'skype-NN', 'with-IN', 'me-PPO', 'this-DT', 'saturday-NR', 'kot.-NN', 'still-RB', 'in-IN', 'milan-NP', 'bro.-NN']
# ['back-RB', 'in-IN', 'stoke-NN', 'on-IN', 'trent-NN', 'for-IN', 'the-AT', '2nd-OD', 'time-NN', 'today!-NN']
# ['first-OD-TL', 'girls-NNS-TL', 'varsity-NN', 'basketball-NN-TL', 'game-NN-TL', 'tomorrow-NR', 'at-IN', '6:00-CD', 'pm-NN', 'then-RB', 'football-NN-TL', 'senior-JJ-TL', 'night-NN', 'at-IN', '7:15-NN', 'pm-NN', 'see-VB', 'you-PPSS', 'there!-NN', 'go-VB', 'saints!-NN']
# ['lightweights-NN', 'vs-NN', 'set-VBN', 'for-IN', 'tuf-NN', '16-CD', 'finale-NN', 'on-IN', 'the-AT', 'fx-NN', 'december-NP', '15-CD', 'card,-NN', 'prelims-NN', 'on-IN', 'fuel-NN', 'tv-NN', 'and-CC', 'facebook.-NN']
# ['slide-NN', 'thru-IN', 'sometime-RB', 'this-DT', 'weekend-NN', 'ill-JJ', 'have-HV', 'somethin-PN', 'yu-NN', 'can-MD', 'sip-NN', 'on-IN', 'lol-NN', 'gotta-VBN+TO', 'make-VB', 'a-AT', 'abc-NP', 'run-VB', 'tomorrow-NR', 'anyway-RB']
# ['the-AT', 'fact-NN', 'that-CS', 'i-NN', 'still-RB', 'havent-NN', 'decided-VBD', 'if-CS', 'im-NN', 'going-VBG', 'to-TO', 'wvu-NN', 'tonight-NR', 'or-CC', 'tomorrow-NR', 'night-NN', 'hmmmm-NN']
# ['sure-RB', 'absolutely---NN', 'i-PPSS', 'meant-VBD', 'out-RP', 'of-IN', 'the-AT', 'bachmann,-NN', 'perry,-NN', 'santorum,-NN', 'herman-NP', 'cain-NP-TL', 'bunch-NN', 'this-DT', 'election.-NN', 'and-CC', 'romney-NN', 'was-BEDZ', 'not-*', 'my-PP$', '1st-NN', 'choice-NN']
# ['re-NN', 'levein-NN', 'discussion-NN', 'on-IN', 'wed.-NN', 'can’t-NN', 'keep-VB', 'changing-VBG', 'boss,-NN', 'but-CC', 'he-PPS', 'is-BEZ', 'far-RB', 'too-QL', 'negative.-NN', 'brazil-NP', 'gone,-NN', 'new-JJ', 'boss-NN', 'cud-NN', 'experiment.-NN']
# ['today-NR', 'in-IN', 'history-NN-TL', 'november-NP', '02,-NN', '1958-CD', 'elvis-NP', 'gave-VBD', 'a-AT', 'party-NN', 'at-IN', 'his-PP$', 'hotel-NN', 'before-CS', 'going-VBG', 'out-RP', 'on-IN', 'maneuvers.-NN', 'he-PPS', 'sang-VBD', 'and...-NN']
# ['hustle-VB', 'cause-NN', 'you-PPSS', 'got-VBD', 'to-TO', 'then-RB', 'kick-NN', 'back-RB', 'n-NN', 'party-NN', 'everyday-JJ', 'like-CS', 'its-PP$', 'fri-NN']
# ['"-NN', 'sam-NP', 'groaned.-NN', '\\""don’t-NN', '/remind/-NN', 'me...\\""-NN', 'he-PPS', 'murmured.-NN', 'he-PPS', 'adjusted-VBN', 'himself-PPL', 'in-IN', 'his-PP$', 'pants-NNS', 'and-CC', 'sat-VBD', 'up.-NN', '\\""we-NN', 'leaving-VBG', 'then?\\"""-NN']
# ['i-PPSS', 'can’t-NN', 'sleep.-NN', 'way-NN-TL', 'too-QL', 'exited-NN', 'about-IN', 'vancouver-NN', 'tomorrow!-NN', 'i’m-NN', 'like-CS', 'a-AT', 'kid-NN', 'at-IN', 'christmas.-NN']
# ['coming-VBG', 'to-TO', 'greenville-NP-TL', 'tomorrow-NR', 'for-IN', 'my-PP$', 'last-AP', 'few-AP', 'days-NNS', 'in-IN', 'sc,-NN', 'then-RB', 'it’s-NN', 'west-NR', 'coast-NN', 'shawwty-NN']
# ['entertainment:-NN', 'tina-NN', 'fey-NN', 'and-CC', 'amy-NP', 'poehler-NN', 'are-BER', 'hosting-VBG', 'the-AT', 'golden-JJ-TL', 'globes,-NN', 'airing-VBG', 'jan-NP', '13.-NN', 'get-VB', 'ready-JJ', 'for-IN', 'a-AT', 'night-NN', 'full-JJ', 'of-IN', 'laughs!!-NN', '-ashley&alyssa-NN']
# ['who’s-NN', 'going-VBG', 'to-TO', 'plymouth-NP', 'town-NN', 'tomorrow?-NN']
# ['i-PPSS', 'bet-VB', 'the-AT', 'clippers-NN', 'are-BER', 'gonna-VBG+TO', 'get-VB', 'in-IN', 'the-AT', 'lakers-NN', 'ass-NN', 'friday-NR', '(today)-NN']
# ['if-CS', 'you-PPSS', 'do-DO', 'another-DT', 'season-NN', 'of-IN', 'big-JJ-TL', 'brother-NN-TL', 'please-VB', 'please-VB', 'please-VB', 'bring-VB', 'friday-NR', 'night-NN', 'live-VB', 'back!!-NN', 'everyone-PN', 'wants-VBZ', 'it-PPS', 'back-RB', 'on!-NN']
# [':-:', 'it’s-NN', 'that-CS', 'you-PPSS', 'can-MD', 'listen-VB', 'to-TO', 'the-AT', 'deluxe-JJ', 'version-NN', 'of-IN', 'tmh-NN', 'on-IN', 'itunes-NN', '9pm-NN', 'gmt-NN', 'on-IN', 'nov-NN', '5th,-NN', 'monday.-NN']
# ['i-NN', 'said-VBD', 'it-PPS', 'b4-NN', 'dat-NN', 'gucci-NN', 'been-BEN', 'promoting-VBG', 'his-PP$', 'mixtape-NN', '2-CD', 'drop-VB', 'on-IN', '10/17-NN', 'since-CS', 'august,-NN', 'gotti-NN', 'just-RB', 'up-RP', '&-CC-TL', 'tried-VBD', '2-CD', 'come-VB', 'out-RP', 'on-IN', 'da-NN', 'same-AP', 'date-NN']
# ['busy-NN', 'day-NN', 'tomorrow,-NN', 'staging-VBG', 'at-IN', 'bliss-NN', 'instead-RB', 'of-IN', 'sustenio!!-NN', 'both-ABX', 'very-QL', 'cool-JJ', 'places.-NN', 'and-CC', 'my-PP$', 'last-AP', 'night-NN', 'in-IN', 'texas.-NN', 'its-PP$', 'gonna-VBG+TO', 'be-BE', 'great!-NN', ':)-NN']
# ['my-PP$', 'pain-NN', 'may-MD', 'be-BE', 'the-AT', 'reason-NN', 'for-IN', 'somebody’s-NN', 'laugh.-NN', 'but-CC', 'my-PP$', 'laugh-NN', 'must-MD', 'never-RB', 'be-BE', 'the-AT', 'reason-NN', 'for-IN', 'somebody’s-NN', 'pain-NN', '--IN', 'charlie-NP', 'ch-NN']
# ['might-NN-TL', 'do-DO', 'my-PP$', 'sport-NN', 'work-NN', 'on-IN', 'the-AT', 'train-NN', 'tomorrow-NR', 'cbb-NN', 'right-JJ', 'now-RB']
# ['just-RB', 'watched-VBD', 'most-QL', 'of-IN', 'movie,missed-NN', 'the-AT', '1st-NN', '20-CD', 'min.sˋut...i-NN', 'thought-VBD', 'y2j-NN', 'was-BEDZ', 'in-IN', 'it!looked-NN', 'like-CS', 'him,said-NN', 'chris-NP', 'jericho-NN', 'in-IN', 'creditsˋut...nah!-NN', '(;-NN']
# ['thursday-NR', 'night-NN', 'is-BEZ', 'reserved-VBN', 'for-IN', 'comedys-NN', 'on-IN', 'nbc,-NN', 'fx-NN', 'and-CC', 'tonight,-NN', 'nfl-NN', 'network.-NN']
# ['at-IN', 'the-AT', 'monday-NR', 'night-NN', 'football-NN', 'game-NN', 'cardinals-NNS-TL', 'vs-NP-TL', 'niners-NN', 'with-IN', 'steve-NP', 'edlefsen-NN', 'and-CC', 'matthew-NP-TL', 'kroon.-NN']
# ['mitt-NN', 'romney-NN', 'falsely-NN', 'claimed-VBD', 'he-PPS', 'saw-VBD', 'his-PP$', 'father-NN', 'march-NN', 'with-IN', 'martin-NP', 'luther-NP', 'king-NN-TL', 'jr.-NP', 'mitt-NN', 'romney-NN', 'what-WDT', 'won’t-NN', 'you-PPSS', 'lie-VB', 'about?-NN']
# ['its-PP$', 'going-VBG', 'down-RP', 'in-IN', 'this-DT', 'saturday!-NN', 'geaux-NN', 'tigers-NNS-TL']
# ['get-VB', 'to-TO', 'see-VB', 'my-PP$', 'big-JJ', 'sis-NN', 'sunday-NN', 'and-CC', 'watch-VB', 'the-AT', 'packers-NPS', 'game!-NN']
# ['not-*', 'only-RB', 'is-BEZ', 'home-NR', 'from-IN', 'china,-NN', 'she’s-NN', 'in-IN', 'la...i-NN', 'called-VBN', 'her-PP$', 'and-CC', 'screamed-VBD', 'mandyyyyyyyyyyyyy...i’m-NN', 'gonna-VBG+TO', 'hug-VB', 'her-PP$', 'for-IN', '2-CD', 'hrs-NN', 'tomorrow!-NN']
# ['may-NP', 'i-PPSS', 'know-VB', 'if-CS', 'there-EX', 'is-BEZ', 'still-RB', 'a-AT', 'chance-NN', 'to-TO', 'meet-VB', 'tiger-NN-TL', 'woods-NNS-TL', 'before-CS', 'he-PPS', 'leaves-VBZ', 'singapore?-NN']
# ['going-VBG', 'to-TO', 'singapore-NN', 'tonight-NR', ':)-NN', 'excited-NN', 'for-IN', 'skyfall-NN', '+-NN', 'penny-NN', 'boarding-VBG', 'tomorrow!-NN']
# ['firework-NN', 'just-RB', 'came-VBD', 'on-IN', 'my-PP$', 'tv-NN', 'and-CC', 'i-PPSS', 'just-RB', 'broke-VBD', 'down-RP', 'and-CC', 'sat-VBD', 'and-CC', 'cried,-NN', 'i-PPSS', 'need-VB', 'help-VB', 'okay-JJ']
# ['you-PPSS', 'ain’t-NN', 'gone-VBN', 'do-DO', 'shit-NN', 'tomorrow-NR', 'we-PPSS', 'gone-VBN', 'see-VB', 'chicken-NN', 'shit-NN']
# ['"my-NN', 'great-JJ', 'grandpa-NN', 'was-BEDZ', 'gonna-VBG+TO', 'march-NN', 'with-IN', 'dr.-NN-TL', 'king-NN-TL', 'but-CC', 'he-PPS', 'said-VBD', '\\""nah-NN', 'man,-NN', 'why-WRB', 'march-NN', 'when-WRB', 'i-PPSS', 'can-MD', 'finger-NN', 'these-DTS', 'white-JJ', 'bitches-NN', 'instead?\\"""-NN']
# ['remember-VB', 'this?-NN', 'santorum:-NN', 'romney,-NN', 'obama-NN', 'healthcare-NN', 'mandates-NN', 'one-CD', 'and-CC', 'the-AT', 'same-AP']
# ['watching-VBG', 'napoleon-NP', 'dynamite-NN', 'with-IN', '=-NN', 'best-JJT', 'friday-NR', 'night-NN', 'ever!-NN']
# ['did-DOD', 'romney’s-NN', 'dad-NN', 'march-NN', 'with-IN', 'dr.king-VBG', 'yes-RB', 'or-CC', 'no-AT', '?-.']
# ['last-AP', 'man-NN-TL', 'standing-VBG', 'season-NN', '2-CD', 'premieres-NN', 'november-NP', '2nd-OD', 'on-IN', 'abc-NP', 'with-IN', 'an-AT', 'election-NN-TL', 'theme-NN', 'via-IN']
# ['bama-NN', 'maintains-VBZ', 'the-AT', 'longest-JJT', 'active-JJ', 'unbeaten-NN', 'streak-NN', 'as-CS', 'they-PPSS', 'march-NN', '(again)-NN', 'to-TO', 'the-AT', 'national-JJ', 'title.-NN', 'roll-NN', 'tide!-NN']
# ['uploading-VBG', 'my-PP$', 'ipod-NN', 'for-IN', 'tht-NN', 'drive-NN', 'back-RB', 'to-TO', 'the-AT', 'o-NN', 'tomorrow-NR']
# ['i’ll-NN', 'donate-VB', '$5-NNS', 'to-TO', 'the-AT', 'homeless-NN', 'guy-NN', 'on-IN', '3rd-OD', 'st.-NN-TL', 'if-CS', 'u-PPO', 'can-MD', 'talk-VB', 'into-IN', 'letting-VBG', 'us-PPO', 'judge-NN', 'the-AT', 'next-AP', 'miss-NP', 'america-NP']
# ['so-RB', 'clattenburg’s-NN', 'alleged-VBN', 'racism-NN', 'may-MD', 'mean-VB', 'end-NN', 'of-IN', 'his-PP$', 'career;-NN', 'terry,-NN', 'suarez,-NN', 'rio-NP', 'use-NN', 'it-PPS', 'and-CC', 'can’t-NN', 'play-VB', 'for-IN', 'a-AT', 'couple-NN', 'of-IN', 'weeks?-NN']
# ['watching-VBG', 'this-DT', 'great-JJ', 'interview-NN', 'with-IN', 'ava-NN', 'duvernay-new-NN', 'film-NN', 'coming-VBG', 'out-RP', 'fri.-NN', 'with-IN', 'the-AT', 'beautiful-JJ', 'nigerian-NN', 'actor-NN', 'from-IN', 'red-JJ-TL', 'tails-NN']
# ['pretty-QL', 'little-JJ-TL', 'liars-NN', 'is-BEZ', 'not-*', 'back-RB', 'until-CS', 'the-AT', '8th-OD', 'of-IN', 'january!!!-NN', 'i’m-NN', 'devastated-VBN']
# ['i-NN', 'like-CS', 'how-WRB', 'each-DT', 'friday-NR', 'the-AT', 'announcers-NNS', 'hype-NN', 'how-WRB', 'alabama-NP', 'can-MD', 'be-BE', 'beat-VB', 'and-CC', 'each-DT', 'monday-NR', 'state-NN', 'how-WRB', 'alabama-NP', 'is-BEZ', 'still-RB', 'number-NN', 'one...-NN']
# ['i’m-NN', 'going-VBG', 'to-TO', 'blockbuster-NN', 'tomorrow-NR', 'to-TO', 'get-VB', 'devil-NN-TL', 'inside-RB', 'if-CS', 'that’s-NN', 'okay??;)-NN']
# ['[espn]-NN', 'sec-NN', 'lunch-NN', 'links:-NN', 'some-DTI', 'linkage-NN', 'for-IN', 'you-PPSS', 'on-IN', 'a-AT', 'thursday:-NN', 'alabama-NP', 'will-MD', 'throw-VB', 'some-DTI', 'different-JJ', 'thing...-NN']
# ['"\\"":-NN', 'better-RBR', 'qb:-NN', 'ben-NP', 'roethlisberger-NN', 'or-CC', 'eli-NP', 'manning?-NN', 'you-PPSS', 'make-VB', 'the-AT', 'call-VB', '--IN', 'and-CC', 'watch-VB', 'them-PPO', 'face-NN', 'off-RP', 'this-DT', 'sunday.\\""-NN', 'tony-NP', 'romo."-NN']
# ['damn-VB', 'only-RB', 'the-AT', '2nd-OD', 'day-NN', 'in-IN', 'the-AT', 'nba-NN', 'season-NN', 'and-CC', 'tony-NP', 'parker-NP', 'already-RB', 'hitting-VBG', 'game-NN', 'winners-NNS']
# ['"thanking-VBG', 'all-ABN', 'my-PP$', 'lucky-JJ', 'stars.-NN', '(no-NN', 'madonna)-NN', '\\""with-NN', 'the-AT', 'sun-NN', 'in-IN', 'the-AT', 'mornin’-NN', '&-CC-TL', 'the-AT', 'moon-NN', 'in-IN', 'the-AT', 'evenin’-NN', 'i’m-NN', 'alright.\\"""-NN']
# ['the-AT', 'philippines-NPS', 'just-RB', 'passed-VBD', 'a-AT', 'law-NN', 'worse-JJR', 'than-CS', 'sopa,-NN', 'which-WDT', 'actually-RB', 'criminalizes-NN', 'criticizing-VBG', 'someone-PN', 'online.-NN']
# ['"emile-NN', 'heskey-NN', 'has-HVZ', 'sure-JJ', 'started-VBD', 'his-PP$', 'a-league-NN', 'career-NN', 'well.-NN', '4-CD', 'goals-NNS', 'in-IN', '3-CD', 'games!-NN', 'may-NP', 'it-PPS', 'continue.-NN', '\\""match-NN', 'stats-NN']
# ['hey-UH', 'it’s-NN', 'natalie-NP', 'the-AT', 'intern-NN', 'at-IN', 'cbs-NN', '47-CD', 'do-DO', 'you-PPSS', 'mind-NN', 'if-CS', 'i-PPSS', 'shadow-NN', 'you-PPSS', 'tomorrow-NR', 'or-CC', 'monday-NR', 'or-CC', 'whenever-WRB', 'it’s-NN', 'convenient-JJ', 'for-IN', 'you?-NN', ':)-NN']
# ['"when-NN', 'i-PPSS', 'was-BEDZ', 'little-AP', 'my-PP$', 'brother-NN', 'liam-NN', 'asked-VBD', 'me-PPO', '\\""is-NN', 'it-PPS', 'tomorrow-NR', 'yet?\\""-NN', 'and-CC', 'i-PPSS', 'replied-VBD', '\\""no,-NN', 'it’s-NN', 'always-RB', 'today.\\""-NN', '"-NN']
# ['you-PPSS', 'are-BER', 'top-NN', 'billing-NN', 'to-TO', 'shakespeare-NP', 'in-IN', 'google-NN', 'but-CC', '2nd-OD', 'in-IN', 'wiki.-NN', 'one,-NN', 'a-AT', 'master-NN', 'of-IN', 'english;-NN', 'the-AT', 'other,-NN', 'from-IN', 'stratford.-NN']
# ['sorry!!-NN', 'still-RB', 'hope-NN', 'to-TO', 'see-VB', 'you-PPSS', 'in-IN', 'los-NP', 'angeles-NP', 'in-IN', 'february!!-NN']
# ['but-CC', 'some-DTI', 'of-IN', 'ya-PPSS', 'need-VB', 'to-TO', 'calm-JJ', 'down,-NN', 'there-EX', 'just-RB', 'snippets!-NN', 'and-CC', 'besides-IN', 'we-PPSS', 'get-VB', 'to-TO', 'hear-VB', 'them-PPO', 'on-IN', 'itunes-NN', 'on-IN', 'monday-NR', 'so-QL', 'it’s-NN', 'not-*', 'really-RB', 'a-AT', 'big-JJ', 'deal!-NN']
# ['gary-NP', 'ablett-NN', 'has-HVZ', 'to-TO', 'be-BE', 'a-AT', 'surely.-NN', 'a-AT', 'lot-NN', 'of-IN', 'losses,-NN', 'but-CC', 'clearly-RB', 'best-JJT', 'and-CC', 'most-QL', 'influential-JJ', 'player-NN', 'in-IN', 'the-AT', '&-CC-TL', 'thommo-NN', '2nd-OD']
# ['these-DTS', 'past-NN', 'few-AP', 'weeks-NNS', 'i-PPSS', 'haven’t-NN', 'been-BEN', 'excited-VBN', 'about-IN', 'scandal,-NN', 'grey’s-NN', 'or-CC', 'fried-VBN', 'chicken-NN', 'thursday....this-NN', 'semester-NN', 'has-HVZ', 'shown-VBN', 'me-PPO', 'no-AT', 'mercy-NN', 'smh-NN']
# ['cheers-NNS', '4-CD', 'the-AT', 'ticket-NN', 'ed-NN', '4-CD', 'wednesday-NN', ',steve-NN', 'looks-VBZ', 'a-AT', 'bit-NN', 'like-CS', 'ricky-NN', 'gervais-NN', 'fucker-NN']
# ['i’ll-NN', 'be-BE', 'in-IN', 'london,-NN', 'within-IN', 'zayn’s-NN', 'birthday-NN', 'the-AT', '12th-OD', 'of-IN', 'january-NN', 'meet-VB', 'you-PPSS', 'there-EX', 'hahaaha-NN', 'dreams-NN', 'and-NN', 'imagination-NN', 'of-NN', 'mine-NN', '..-NN']
# []
# ['but-CC', 'honestly-RB', 'i-PPSS', 'think-VB', 'miami-NP-TL', 'may-MD', 'be-BE', 'the-AT', 'alabama-NP', 'of-IN', 'the-AT', 'nba.-NN']
# ['well-UH', 'said-VBD', 'on-IN', 'hmw.-NN', 'can-MD', 'you-PPSS', 'now-RB', 'address-NN', 'why-WRB', 'texans-NPS', 'fans-NNS', 'file-NN', 'out-RP', 'of-IN', 'the-AT', 'stadium-NN', 'midway-RB', 'through-IN', 'the-AT', '4th-OD', 'qtr-NN', 'of-IN', 'every-AT', 'game?-NN']
# ['girl-NN-TL', 'exactly-RB', 'but-CC', 'i’m-NN', 'mad-JJ-TL', 'because-CS', 'they-PPSS', 'pushed-NN', 'gotti-NN', 'date-NN-TL', 'back!-NN', 'but-CC', 'fuck-VB', 'all-ABN', 'that-DT', 'november-NN', '23-CD', 'rva!-NN', 'shawty-NN', 'how-WRB', 'you-PPSS', 'acting??-NN']
# ['on-IN', 'the-AT', 'jersey-NP-TL', 'shore,-NN', 'emotion-NN', 'outweighs-NN', 'cost-NN', 'of-IN', 'rebuilding:-NN', 'bay-NN', 'head,-NN', 'n.j./boston-NN', '(reuters)-NN', '--IN', 'the-AT', 'people-NNS', 'of-IN', 'the-AT', 'jersey-NP-TL', 'shore-NN-TL', 'may-MD', 'feel-VB', '...-NN']
# ['the-AT', 'may-MD', 'have-HV', 'the-AT', 'best-JJT', 'defense..but-NN', 'they-PPSS', 'still-RB', 'lost-VBN', 'to-TO', 'the-AT', 'packers-NPS']
# ['sad-JJ', 'scenes-NNS', 'about-IN', 'underoath-NN', 'splitting.-NN', 'off-RP', 'to-TO', 'newcastle-NP', 'tomorrow-NR', 'for-IN', 'the-AT', 'weekend.-NN', 'try-VB', 'catch-VB', 'the-AT', 'game-NN', 'too.-NN', 'if-CS', 'yr-NN', 'about-IN']
# ['anybody-PN', 'at-IN', 'the-AT', 'trib:-NN', 'where-WRB', 'is-BEZ', 'ike-NP', 'taylor’s-NN', 'friday-NR', 'column?-NN', 'sucks-NN', 'i-PPSS', 'can’t-NN', 'find-VB', 'it.-NN', 'first-OD-TL', 'one-CD', 'i’ve-NN', 'actually-RB', 'looked-VBD', 'forward-RB', 'to-TO', 'reading.-NN']
# ['get-VB', 'pumped-VBD', 'for-IN', 'the-AT', 'new-JJ', 'season-NN', 'of-IN', 'justified!!-NN']
# ['sunderland-NN', 'have-HV', 'some-DTI', 'shit-NN', 'fans!-NN', 'they-PPSS', 'all-ABN', 'were-BED', 'going-VBG', 'home-NR', 'with-IN', '10-CD', 'mins-NN', 'of-IN', 'the-AT', 'game-NN', 'left.-NN', 'demba-NN', 'ba-NN', 'still-RB', '2nd-OD', 'top-NN', 'scorer-NN']
# ['1.she-NN', 'is-BEZ', 'in-IN', 'love-NN', 'with-IN', 'zayn-NN', 'malik-NN', 'and-CC', 'beau-NP', 'brooks-NP', '2.ive-NN', 'known-VBN', 'her-PP$', 'since-CS', '5th-OD', 'grade(;-NN', '3.she-NN', 'is-BEZ', 'so-QL', 'tiny!-NN']
# ['i-PPSS', 'hope-NN', 'anderson-NN', 'starts-VBZ', 'tomorrow’s-NN', 'game-NN', 'he-PPS', 'did-DOD', 'very-QL', 'against-IN', 'chelsea-NN']
# ['look-VB', 'forward-RB', 'to-TO', 'seeing-VBG', 'you-PPSS', 'in-IN', 'newcastle-NP', 'tomorrow-NR', 'night!-NN', 'i’ll-NN', 'be-BE', 'front-NN', 'row-NN', 'wearing-VBG', 'a-AT', 'broski-NN', 't-shirt!-NN']
# ['the-AT', 'fiesta-NN', 'bowl.-NN', 'and-CC', 'i-PPSS', 'was-BEDZ', 'surprised-VBN', 'to-TO', 'see-VB', 'they-PPSS', 'were-BED', 'ranked-VBN', '6th-OD', 'in-IN', 'the-AT', 'polls.-NN', 'cuse-NN', 'don’t-NN', 'get-VB', 'alot-NN', 'of-IN', 'love-NN', 'in-IN', 'football-NN', 'land-NN']
# ['it’ll-NN', 'prolly-NN', 'sound-NN', 'like-CS', 'the-AT', '1st-NN', 'pluto-NN', 'which-WDT', 'was-BEDZ', '...................-NN', 'ok,-NN', 'i-PPSS', 'wonder-VB', 'if-CS', 'he-PPS', 'gone-VBN', 'have-HV', 'kanye-NN', 'on-IN', 'it-PPS']
# ['i’m-NN', 'going-VBG', 'to-TO', 'the-AT', 'texans-NPS', 'game-NN', 'sunday!-NN']
# ['new-JJ-TL', 'series-NN', 'of-IN', 'greys-NN', 'anatomy-NN', 'starts-VBZ', 'on-IN', '07-NN', 'november-NP', '--IN', 'one-CD', 'good-JJ', 'thing-NN', 'about-IN', 'winter-NN', 'is-BEZ', 'the-AT', 'return-NN', 'of-IN', 'the-AT', 'best-JJT', 'us-NN', 'shows!-NN']
# ['jerred-NN', 'tomorrow-NR', 'followed-VBD', 'by-IN', 'a-AT', 'day-NN', 'of-IN', 'nothing-PN', 'but-CC', 'xbox-NN', 'sounds-NNS', 'great.-NN', 'then-RB', 'next-AP', 'friday.-NN', 'so-RB', 'much-AP', 'excite.-NN']
# ['"-NN', '\\""wicked\\""-NN', 'welcome-JJ', 'to-TO', 'new-JJ', 'england!-NN', 'are-BER', 'you-PPSS', 'still-RB', 'in-IN', 'boston?-NN', 'im-NN', 'going-VBG', 'to-TO', 'mass-NN', 'tomorrow-NR', 'to-TO', 'my-PP$', 'friends-NNS', 'house"-NN']
# ['we-PPSS', 'all-ABN', 'know-VB', 'that-CS', 'ike-NP', 'taylor-NP', 'got-VBD', 'the-AT', '3rd-OD', 'top-JJS', 'player-NP', 'of-IN', 'the-AT', 'game-NN', 'for-IN', 'his-PP$', 'swaggin’-NN', 'prowess-NN', 'only.-NN']
# ['suarez-NN', 'is-BEZ', '1-CD', 'yc-NN', 'away-RB', 'from-IN', 'a-AT', 'domestic-JJ', 'suspension.-NN', 'if-CS', 'he-PPS', 'picks-VBZ', 'up-RP', 'a-AT', 'yc-NN', 'this-DT', 'sunday-NR', 'vs-NP-TL', 'newcastle,-NN', 'then-RB', 'he-PPS', 'will-MD', 'miss-VB', 'the-AT', 'clash-NN', 'at-IN', 'sb-NN', 'next-AP', 'w/end.-NN']
# ['two-thirds-NN', 'of-IN', 'the-AT', 'ncaa-NN', 'football-NN', 'season-NN', 'are-BER', 'completed.-NN', 'the-AT', 'race-NN', 'for-IN', 'the-AT', 'bcs-NN', 'title-NN', 'game-NN', 'is-BEZ', 'heading-NN', 'to-TO', 'a-AT', 'huge-JJ', 'controversy.-NN']
# ['is-BEZ', 'demba-NN', 'ba-NN', 'sunderlands-NN', '2nd-OD', 'top-NN', 'scorer,-NN', 'i-PPSS', 'believe-VB', 'he-PPS', 'is.-NN']
# ['fam,-NN', 'twitpic-NN', 'your-PP$', 'halloween-NP', 'costume-NN', 'to-TO', 'win-VB', 'a-AT', 'pair-NN', 'of-IN', 'tickets-NNS', 'to-TO', 'see-VB', 'the-AT', 'hawks-NN', 'defeat-NN', 'the-AT', 'rockets-NN', 'this-DT', 'friday-NR']
# ['sitting-VBG', 'at-IN', 'home-NR', 'on-IN', 'a-AT', 'saturday-NR', 'night-NN', 'doing-VBG', 'absolutely-QL', 'nothing...-NN', 'guess-VB', 'i’ll-NN', 'just-RB', 'watch-VB', 'greys-NN', 'anatomy-NN', 'all-ABN', 'night.-NN']
# ['cardinals-NNS-TL', 'try-VB', 'to-TO', 'pick-VB', 'up-RP', 'the-AT', 'pieces-NNS', 'against-IN', 'packers:-NN', 'embarrassed-NN', 'on-IN', 'monday-NR', 'night,-NN', 'the-AT', 'arizona-NP', 'cardinals-NNS-TL', 'are-BER', 'left...-NN']
# ['dear-JJ', 'one-CD', 'was-BEDZ', 'driving-VBG', 'from-IN', 'newcastle.-NN', 'sunday?-NN', 'so-RB', 'glad-JJ', 'liked-VBD', 'it-PPS', '--IN', 'it-PPS', 'was-BEDZ', 'great-JJ', 'to-TO', 'meet-VB', 'you-PPSS', 'norelle!-NN']
# ['the-AT', '6th-OD', 'chapter-NN', 'talks-NNS', 'about-IN', 'malcolm-NN', 'x-NN', 'and-CC', 'i-PPSS', 'think-VB', 'martin-NN', 'luther-NN', 'king,.he-NN', 'kinda-QL', 'contrasts-NNS', 'them-PPO']
# ['5)-NN', 'don’t-NN', 'mention-VB', 'the-AT', 'score:-NN', '𠆝o-NN', 'we-PPSS', 'want-VB', 'revenge?-NN', 'no.’-NN', '--IN', 'wenger-NN', 'ahead-RB', 'of-IN', 'the-AT', 'united-VBN-TL', 'game-NN', 'on-IN', 'saturday-NN']
# ['online-NN', 'it-PPS', 'said-VBD', 'one-CD', 'direction-NN-TL', 'tix-NN', 'for-IN', 'paris-NP', 'april-NP', '29th-OD', '2013-NN', 'go-VB', 'on-IN', 'sale-NN', 'at-IN', '10am,-NN', 'what-WDT', 'site-NN', 'can-MD', 'you-PPSS', 'buy-VB', 'tickets!-NN']
# ['u-NP', 'going-VBG', 'to-TO', 'chalmers-NN', 'tomorrow?-NN']
# ['off-RP', 'to-TO', 'anfield-NN', 'on-IN', 'sunday-NR', 'for-IN', 'lfc-NN', 'vs-NP-TL', 'newcastle-NP', 'with-IN']
# ['mr-NN', 'howard-NP', 'webb-NP', 'did-DOD', 'a-AT', 'fantastic-JJ', 'comback-NN', 'in-IN', 'chelsea-NN', 'match-VB', '05-CD', 'february-NP', '2012-NN', '--IN', 'with-IN', 'the-AT', 'help-VB', 'of-IN', 'two-CD', 'magic-JJ', 'penalties-NNS', 'of-IN', 'course...-NN']
# ['on-IN', 'the-AT', 'jersey-NP-TL', 'shore,-NN', 'emotion-NN', 'outweighs-NN', 'cost-NN', 'of-IN', 'rebuilding:-NN', 'bay-NN', 'head,-NN', 'n.j./boston,-NN', 'nov-NN', '2-CD', '(reuters)-NN', '--IN', 'the-AT', 'people-NNS', 'of...-NN']
# ['cowboys-NN', 'will-MD', 'beat-VB', 'the-AT', 'falcons-NN', 'sunday-NN']
# ['check-VB', 'out-RP', 'sir-NP', 'terry-NP', 'leahy-NN', 'article-NN', 'in-IN', 'saturday’s-NN', 'telegraph-NN-TL', 'weekend-NN', 'section-NN', 're-NN', 'why-WRB', 'he-PPS', 'invested-VBN', 'in-IN', 'gcse-NN', 'maths-NN', 'resource-NN']
# ['plagiarism.-NN', 'sopa’s-NN', 'gonna-VBG+TO', 'get-VB', 'you-PPSS', 'on-IN', 'october-NN', '3.-NN']
# ['vegas-NP', 'beat:-NN', 'ellen-NP', 'reveals-VBZ', 'that-CS', 'madonna-NP', 'helped-VBD', 'her-PP$', 'come-VB', 'out-RP', 'of-IN', 'the-AT', 'closet:-NN', 'tuesday’s-NN', 'episode-NN', 'of-IN', 'ellen-NP', 'featured-VBN', 'th...-NN']
# ['can’t-NN', 'wait-VB', 'to-TO', 'go-VB', 'to-TO', 'the-AT', 'wvu-NN', 'vs.-IN', 'tcu-NN', 'game-NN', 'on-IN', 'saturday-NR']
# ['very-QL', 'much-AP', 'looking-VBG', 'forward-RB', 'to-TO', 'saturday.-NN', 'afternoon-NN', 'tea-NN', 'and-CC', 'firework-NN', 'display-NN', 'at-IN', 'the-AT', 'celtic-JJ', 'manor.-NN']
# ['hahaaa.-NN', 'well-RB', 'if-CS', 'u-PPO', 'wanna-VB+TO', 'take-VB', 'me-PPO', 'to-TO', 'brazil-NN', 'i-NN', 'ain’t-NN', 'gonn-NN', 'say-VB', 'no.-NN-HL', 'how-WRB', 'about-IN', 'viva-FW-JJ', 'brazil-NN', 'tho-NN', 'next-AP', 'friday-NR', 'night?-NN', 'bit-NN', 'cheaper-JJR', 'xxx-NN']
# ['16:46-NN', 'steven-NN', 'pourier,-NN', 'jr.-NP', '(olc)-NN', 'made-NN', 'the-AT', '1-CD', 'shot-NN', 'free-JJ-TL', 'throw.-NN', 'dasu-NN', 'leads-VBZ', '8-CD', '--IN', '6-CD', 'in-IN', 'the-AT', '1st-NN', 'half.-NN']
# ['trent-NN', 'richardson-NP', 'has-HVZ', 'the-AT', 'browns-NN', 'out-RP', 'to-TO', 'a-AT', '7-0-NN', 'lead-VB', 'over-IN', 'the-AT', 'chargers-NN', 'on-IN', 'sunday.-NN']
# ['"gerrard:-NN', '\\""every-NN', 'single-AP', 'time-NN', 'they-PPSS', 'got-VBD', 'the-AT', 'ball-NN', 'to-TO', 'their-PP$', 'keeper-NN', 'it-PPS', 'came-VBD', 'in-IN', 'long\\"".-NN', 'sunday’s-NN', 'long-JJ', 'ball-NN', 'stats-NN', '--IN', 'tim-NP', 'howard-NP', '(15),-NN', 'brad-NN', 'jones-NP', '(20)."-NN']
# ['muhammad-NP', 'ali-NN', 'came-VBD', 'into-IN', 'my-PP$', 'work-NN', 'tonight-NR', 'to-TO', 'eat...i-NN', 'think-VB', 'that-CS', 'being-BEG', 'in-IN', 'the-AT', 'presence-NN', 'of-IN', 'a-AT', 'legend-NN', 'made-VBN', 'this-DT', 'tuesday-NR', 'pretty-QL', 'legit.-NN']
# ['"\\""i-NN', 'didn’t-NN', 'want-VB', 'new-JJ-TL', 'york-NP-TL', 'to-TO', 'miss-VB', 'my-PP$', 'madonna-NP', 'show.-NN', 'get-VB', 'ready-JJ', 'for-IN', 'monday!-NN', 'it’s-NN', 'gonna-VBG+TO', 'be-BE', 'on-IN', 'wnbc!\\""-NN', 'there-EX', 'is-BEZ', 'a-AT', 'god<333333-NN', 'thanks-NNS', 'ellen-NP', ':𠆓"-NN']
# ['maybe-RB', 'ksrc-NN', 'needs-NNS', 'a-AT', 'wrasslin’-NN', 'recap-NN', 'then.-NN', 'once-RB', 'mentioned-VBN', 'we-PPSS', 'may-MD', 'have-HV', 'things-NNS', 'about-IN', 'the-AT', 'bachelor-NN-TL']
# ['life-NN-TL', 'just-RB', 'isn’t-NN', 'the-AT', 'same-AP', 'when-WRB', 'there-EX', 'is-BEZ', 'no-AT', 'pretty-QL', 'little-JJ-TL', 'liars-NN', 'on-IN', 'tuesday-NR', 'nights.-NN']
# ['(times-NN', 'pic)-NN', 'lsu-NN', 'coach-NN-TL', 'les-FW-AT-TL', 'miles-NP', 'said-VBD', 'bcs-NN', 'title-NN', 'game-NN', 'has-HVZ', 'no-AT', 'bearing-VBG', 'on-IN', 'saturday’s-NN', 'matchup-NN', 'with-IN', 'alabama-NP']
# ['"\\"":-NN', 'we-PPSS', 'look-VB', 'like-CS', 'uva.-NN', 'there-EX', 'i-PPSS', 'said-VBD', 'it.\\""-NN', 'so-RB', 'sad-JJ', 'but-CC', 'so-QL', 'very-QL', 'true..-NN', 'november-NP', '24th-OD', 'is-BEZ', 'going-VBG', 'to-TO', 'be-BE', 'a-AT', 'circus"-NN']
# ['class-NN-TL', 'early-JJ', 'in-IN', 'the-AT', 'mornjng-NN', '=\\-NN', 'it’s-NN', 'bedtime!-NN', 'but-CC', 'do-DO', 'get-VB', 'to-TO', 'see-VB', 'my-PP$', 'sam-NP', 'tomorrow-NR', ':)-NN']
# ['hey-UH', ':)-NN', 'support-NN', 'to-TO', 'the-AT', 'philippines?-NN', 'cybercrime-NN', 'law-NN-TL', 'to-TO', 'be-BE', 'in-IN', 'full-JJ', 'effect-NN', 'tomorrow.-NN', 'our-PP$', 'version-NN', 'of-IN', 'sopa-NN']
# ['"\\"":-NN', '\\""despite-NN', 'what-WDT', 'you-PPSS', 'may-MD', 'have-HV', 'heard,-NN', 'i-PPSS', 'actually-RB', 'do-DO', 'give-VB', 'a-AT', 'shit.\\""-NN', '--honey-NN', 'badger,-NN', 'in-IN', 'an-AT', 'interview-NN', 'with-IN', 'piers-NP', 'morgan\\""-NN', '"-NN']
# ['i-PPSS', 'get-VB', 'to-TO', 'see-VB', 'ces-NN', 'tomorrow!!!!!-NN', 'best-JJT', 'news-NN', 'since-CS', 'the-AT', 'hurricane.-NN', 'he-PPS', 'better-JJR', 'not-*', 'forget-VB', 'his-PP$', 'flashlight!-NN']
# ['can-MD', 'mike-NP', 'brown-NP', 'play-VB', 'golf?-NN', 'he-PPS', 'may-MD', 'need-VB', 'to-TO', 'hit-VBD', 'up-RP', 'the-AT', 'stanford-NP-TL', 'women’s-NN', 'team-NN', 'w-NN', 'ty-NN', 'willingham-NN', 'after-IN', 'this-DT', 'start,-NN', 'honestly...-NN']
# ['please-VB', 'join-VB', 'and-CC', 'myself-PPL', 'this-DT', 'tuesday-NR', '@-NN', '8:30-CD', 'pm-NP', 'as-CS', 'we-PPSS', 'discuss-VB', 'hib.-NN', 'special-JJ-TL', 'guest-NN', 'moderator-NN', 'glad-JJ', 'to-TO', 'have-HV', 'you.-NN']
# ['remember-VB', 'the-AT', 'midterm-NN', 'elections?-NN', 'remember-VB', 'the-AT', 'wisconsin-NP', 'recall?-NN', 'just-RB', 'wait-VB', 'for-IN', 'next-AP', 'tuesday.-NN']
# ['just-RB', 'been-BEN', 'informed-VBN', 'my-PP$', 'police-NN', 'hat-NN', 'from-IN', 'saturday-NR', 'has-HVZ', 'made-VBN', 'a-AT', 'home-NR', 'in-IN', 'chalmers-NPS', 'and-CC', 'no-AT', 'doubt-NN', 'has-HVZ', 'made-VBN', 'a-AT', 'home-NR', 'with-IN', 'some-DTI', 'skank-NN', 'sob-NN']
# ['it’s-NN', 'either-CC', 'ua-NN', 'or-CC', 'au-NN', 'for-IN', 'grad-NN', 'school.-NN', 'as-CS', 'much-AP', 'as-CS', 'i-PPSS', 'love-NN', 'alabama,-NN', 'i’m-NN', 'thinking-VBG', 'auburn-NP', 'may-MD', 'be-BE', 'the-AT', 'better-JJR', 'choice-NN', 'for-IN', 'me.-NN']
# ['watched-NN', 'a-AT', 'pride-NN-TL', 'and-CC', 'prejudice-NN-TL', 'play-VB', 'and-CC', 'then-RB', 'the-AT', 'season-NN', 'finale-NN', 'of-IN', 'the-AT', '2nd-OD', 'season-NN', 'of-IN', 'downton-NN', 'abbey.-NN', 'tonight-NR', 'is-BEZ', 'so-QL', 'british.-NN']
# ['"-NN', 'devil’s-NN', 'in-IN', 'the-AT', 'house-NN', 'of-IN', 'the-AT', 'rising-VBG', 'sun.-NN', 'chicken’s-NN', 'in-IN', 'the-AT', 'bread-NN', 'pan-NN', 'picking-VBG', 'out-RP', 'dough,-NN', 'granny-NN', 'does-DOZ', 'your-PP$', 'dog-NN', 'bite,-NN', '\\""no-NN', 'child,-NN', 'no\\"""-NN']
# ['i-NN', 'hate-VB', 'how-WRB', 'mlk-NN', 'jr-NN', 'got-VBD', 'caught-VBD', 'apewalkin-NN', 'at-IN', 'the-AT', 'selma-NP', 'march-NP', '(reason-NN', 'why-WRB', 'white-JJ', 'people-NNS', 'call-VB', 'us-PPO', 'monkeys)-NN']
# ['napoleon-NP', 'dynamite-NN', 'may-MD', 'be-BE', 'the-AT', 'most-QL', 'awkward-JJ', 'person-NN', 'ever-RB']
# ['i’m-NN', 'not-*', 'sure-JJ', 'how-WRB', 'teddy-NP', 'bridgewater-NP', 'playing-VBG', 'in-IN', 'the-AT', 'orange-NP-TL', 'bowl-NN-TL', 'will-MD', 'go-VB', 'over-IN', 'in-IN', 'miami.-NN', 'we-PPSS', 'may-MD', 'find-VB', 'out.-NN']
# ['--IN', 'spotted:-NN', 'i-PPSS', 'just-RB', 'saw-VBD', 'elvis,-NN', 'i’m-NN', 'beginning-NN', 'to-TO', 'like-CS', 'the-AT', 'temporary-JJ', '7th-OD-TL', 'floor-NN', 'office.-NN', ';)-NN']
# ['got-VBD', 'to-TO', 'rockdale-NN', 'today-NR', 'and-CC', 'going-VBG', 'back-RB', 'to-TO', 'houston-NN', 'tomorrow-NR', 'thank-NN', 'god!-NN']
# ['you-PPSS', 'got-VBD', 'a-AT', 'sweet-JJ', 'shout-VB', 'out-RP', 'at-IN', 'a-AT', 'jon-NP', 'huntsman-NN', 'jr-NN', 'speech-NN', 'in-IN', 'st.-NN-TL', 'louis-NP', 'monday-NR', 'night.-NN', 'well-UH', 'done!-NN']
# ['can-MD', 'you-PPSS', 'pay-VB', 'on-IN', 'the-AT', 'gate-NN', 'on-IN', 'saturday-NR', 'at-IN', 'bolton-NN', 'or-CC', 'not?-NN']
# ['china-NP', 'to-TO', 'open-JJ', 'cultural-JJ', 'centre-NN', 'in-IN', 'nepal:-NN', 'kathmandu,-NN', 'nov-NN', '2-CD', '(ians)-NN', 'china-NP', 'is-BEZ', 'going-VBG', 'to-TO', 'open-JJ', 'a-AT', 'cultural-JJ', 'cen...-NN']
# ['why-WRB', 'is-BEZ', 'jay-NP', 'cutler-NN', 'good-JJ', 'in-IN', 'the-AT', '4th-OD', 'qtr-NN', 'and-CC', 'not-*', 'others?-NN', 'good-JJ', 'question,-NN', 'espn.-NN', 'could-MD', 'be-BE', 'worse,-NN', 'though;-NN', 'he-PPS', 'could-MD', 'be-BE', 'tony-NP', 'romo.-NN']
# ['pacers-NN', 'fans-NNS', 'are-BER', 'going-VBG', 'to-TO', 'have-HV', 'fun-NN', 'on-IN', 'saturday...-NN']
# ['youtube-NN', 'improves-VBZ', 'upload-NN', 'process-NN', 'with-IN', 'optional-JJ', 'notifications-NN', 'and-CC', 'new-JJ', 'tags-NNS', 'editor:-NN', 'google-NN', 'on-IN', 'thursday-NR', 'announced-VBD', 'th...-NN']
# ['ay-NN', 'up-RP', 'you-PPSS', 'still-RB', 'want-VB', 'me-PPO', 'to-TO', 'get-VB', 'you-PPSS', 'a-AT', 'pair-NN', 'of-IN', 'tickets-NNS', 'for-IN', 'the-AT', 'sunderland-NN', 'match-VB', 'on-IN', '2nd-OD', 'jan-NP', '(7.45pm-NN', 'ko)?-NN']
# ['congratulations-NNS', 'on-IN', 'scoring-VBG', 'your-PP$', 'first-OD', 'goal-NN', 'for-IN', 'swansea-NN', 'yesterday.-NN', 'may-NP', 'i-PPSS', 'say-VB', 'that-CS', 'you-PPSS', 'look-VB', 'exactly-RB', 'like-CS', 'jonas-NN', 'gutierrez-NN', '!-.']
# ['a-AT', 'lot-NN', 'of-IN', 'work-NN', 'goes-VBZ', 'into-IN', 'to-TO', 'showing-VBG', 'a-AT', 'movie-NN', 'under-IN', 'the-AT', 'stars!-NN', 'come-VB', 'out-RP', 'tomorrow-NR', 'night-NN', 'at-IN', 'watch-VB', 'joyful-NN', 'noise-NN', 'on-IN', 'our...-NN']
# ['thanks-NNS', 'to-TO', 'norton-NP', 'junior-JJ-TL', 'school-NN-TL', 'for-IN', 'friday’s-NN', 'superb-JJ', 'op-NN', 'anticipate-NN', 'assembly-NN', 'and-CC', 'the-AT', 'fab-NN', 'singing.-NN', 'katy-NN', 'perry’s-NN', 'firework-NN', 'had-HVD', 'us-PPO', 'beaming-VBG', 'all-ABN', 'day!-NN']
# ['contraband-NN', 'was-BEDZ', 'prolly-NN', 'the-AT', 'worst-JJT', 'below-IN', 'average-JJ', 'movie-NN', 'i-PPSS', 'ever-RB', 'sat-VBD', 'and-CC', 'finished-VBN', 'watching-VBG', 'in-IN', 'my-PP$', 'life-NN']
# ['|-NN', 'that-DT', 'way,-NN', 'the-AT', 'orange-NP-TL', 'bowl-NN-TL', 'would-MD', 'always-RB', 'be-BE', 'a-AT', 'part-NN', 'of-IN', 'me.-NN', 'i-PPSS', 'think-VB', 'it-PPS', 'was-BEDZ', 'a-AT', 'wise-JJ', 'choice.-NN', 'shit,-NN', 'is-BEZ', 'it-PPS', 'thursday-NR', 'yet?-NN', 'game-NN-TL', 'time!-NN']
# ['love-NN-TL', 'my-PP$', 'new-JJ', '.i-NN', 'mean-VB', 'my-PP$', 'ipod-NN', 'touch.5th-NN', 'generation.does-NN', 'everything-PN', 'but-CC', 'make-VB', 'phone-NN', 'calls-VBZ', 'and-CC', 'has-HVZ', 'no-AT', 'gps-NN', 'ability.i-NN', 'don’t-NN', 'need-VB', 'those-DTS', 'options.-NN']
# ['in-IN', 'other-AP', 'related-VBN', 'news,-NN', 'you-PPSS', 'know-VB', 'there’s-NN', 'no-AT', 'parks-NNS-TL', 'tomorrow?-NN']
# ['gold-JJ-TL', 'edges-NNS', 'down-RP', 'ahead-RB', 'of-IN', 'us-NN', 'jobs-NNS', 'data:-NN', 'singapore-NN', '(reuters)-NN', '--IN', 'gold-JJ-TL', 'edged-VBD', 'lower-JJR', 'on-IN', 'friday,-NN', 'with-IN', 'investors-NNS', 'waiting-VBG', '...-NN']
# ['guarantee-NN', 'if-CS', 'i-PPSS', 'go-VB', 'to-TO', 'maths-NN', 'tomorrow-NR', 'ill-JJ', 'spend-VB', 'the-AT', 'whole-JJ', 'time-NN', 'talking-VBG']
# ['i-PPSS', 'will-MD', 'watch-VB', 'coach-NN-TL', 'stews-NN', 'fiesta-NN', 'bowl-NN-TL', 'speech-NN', 'before-CS', 'the-AT', 'game-NN', 'tomorrow.-NN', 'just-RB', 'seems-VBZ', 'right-JJ', 'for-IN', 'some-DTI', 'reason.-NN', 'i-PPSS', 'know-VB', 'he-PPS', 'is-BEZ', 'smiling-VBG', 'at-IN', 'this-DT', 'team.-NN']
# ...
# ['is-BEZ', 'gonna-VBG+TO', 'be-BE', 'in-IN', 'louisville,-NN', 'kentucky-NP', 'tomorrow-NR', '&-CC-TL', 'i-PPSS', 'can’t-NN', 'go-VB', 'to-TO', 'the-AT', 'show.-NN', 'i-PPSS', 'guess-VB', 'i’ll-NN', 'just-RB', 'sit-VB', 'and-CC', 'listen-VB', 'to-TO', 'his-PP$', 'music-NN', '&-CC-TL', 'pretend-VB']
# [':-:', 'ben-NP', 'amos-NP', '(hull-NN', 'city)-NN', 'into-IN', 'extra-JJ', 'time-NN', '1-1,-NN', 'in-IN', 'the-AT', '1st-NN', 'round-JJ', 'of-IN', 'the-AT', 'league-NN-TL', 'cup.-NN']
# ['wish-VB', 'my-PP$', 'grammy-NN', 'was-BEDZ', 'here-RB', 'with-IN', 'me-PPO', 'to-TO', 'celebrate-VB', 'my-PP$', 'birthday-NN', 'on-IN', 'sunday-NR']
# ['michael-NP', 'jackson-NP', 'bad-JJ', '25-CD', 'will-MD', 'air-NN', 'november-NP', '22-CD', 'on-IN', 'abc.-NN', 'make-VB', 'sure-JJ', 'you-PPSS', 'watch-VB', 'it!-NN', ':)-NN']
# ['"-NN', 'forget-VB', 'about-IN', 'dook-NN', 'now-RB', 'we-PPSS', 'own-JJ', 'that-CS', 'series-NN', 'anyways!-NN', 'let’s-NN', '\\""""beat-NN', 'state\\""""-NN', 'this-DT', 'saturday-NN', 'as-CS', 'we-PPSS', 'continue-VB', 'on-IN', 'to-TO', 'a-AT', 'succesful-NN', 'season."-NN']
# ['fifa-NN', 'is-BEZ', 'weird-JJ', 'sometimes:-NN', 'you-PPSS', 'may-MD', 'remember-VB', 'the-AT', 'fifa-NN', '12-CD', 'video-NN', 'where-WRB', 'andy-NP', 'carroll-NP', 'starting-VBG', 'trying-VBG', 'to-TO', 'hump-NN', 'iker-NN', 'casi...-NN']
# ['you’re-NN', 'saying-VBG', 'perseverance-NN', 'in-IN', 'all-ABN', 'instances.-NN', 'that-DT', 'doesn’t-NN', 'mean-VB', 'is-BEZ', 'equivalent-JJ', 'to-TO', '25-CD', 'jan-NP', 'revolution.-NN', 'see-VB', 'the-AT', 'diff?-NN']
# ['i-PPSS', 'got-VBD', 'the-AT', 'dream-NN-TL', 'high-JJ-TL', '2-CD', 'soundtrack-NN', 'and-CC', 'the-AT', 'f(x)-NN', 'album,-NN', 'then-RB', 'i’ll-NN', 'be-BE', 'collecting-VBG', 'the-AT', 'sfs-NN', 'album-NN', 'tomorrow-NR', ':)-NN', 'they-PPSS', 'ran-VBD', 'out-RP', 'of-IN', 'sherlock!-NN']
# ['theo-NN', 'vs-NP-TL', 'evra-NN', 'on-IN', 'saturday.-NN', 'wenger-NN', 'make-VB', 'this-DT', 'happen.-NN']
# ['long-JJ-TL', 'drive-NN', 'too-QL', 'kentucky-NP', 'tomorrow-NR', 'hopefully-RB', 'gonna-VBG+TO', 'get-VB', 'the-AT', 'big-JJ', 'buck-NN', 'we-PPSS', 'caught-VBD', 'on-IN', 'cam,-NN', 'at-IN', 'least-AP', 'we-PPSS', 'got-VBD', 'playing-VBG', 'in-IN', 'the-AT', 'chevy!-NN', '<3-NN']
# ['looking-VBG', 'forward-RB', 'to-TO', 'seeing-VBG', 'the-AT', 'illegal-NN', 'eagles-NNS-TL', 'at-IN', 'dorking-VBG', 'tomorrow-NR', 'night-NN', 'with-IN', 'lin-NN', '&-CC-TL', 'amigo.-NN', 'best-JJT', 'eagles-NNS-TL', 'tribute-NN', 'band-NN', 'around.-NN']
# ['happy-JJ-TL', 'valentine’s-NN', 'day-NN', 'my-PP$', 'love..-NN', 'november-NP', 'is-BEZ', 'coming-VBG', '<3-NN']
# ['anonymous-NN', 'asked:-NN', 'would-MD', 'we-PPSS', 'have-HV', 'a-AT', 'chance-NN', 'at-IN', 'seeing-VBG', 'you-PPSS', 'for-IN', 'topless-NN', 'tuesday?-NN']
# ['pakistan-NP', 'approves-VBZ', 'liberalised-NN', 'visa-NN', 'accord-NN', 'with-IN', 'india-NP', '--IN', 'islamabad,-NN', 'nov-NN', '1-CD', '(ians)-NN', 'pakistan-NP', 'has-HVZ', 'approved-VBN', 'a-AT', 'liberalised-NN', 'v...-NN']
# ['fabio-NN', 'capello-FW-NN-TL', '(russia’s-NN', 'head-coach)-NN', 'wishes-VBZ', 'cristiano’s-NN', 'injury-NN', 'was-BEDZ', 'more-QL', 'serious.-NN', '(russia-NN', 'will-MD', 'play-VB', 'against-IN', 'portugal-NP', 'tomorrow-NR', 'in-IN', 'the-AT', 'wcq)-NN']
# ['hey-UH', 'nevada-NP', 'tweeps-NN', 'remember-VB', 'tomorrow-NN', 'is-BEZ', 'the-AT', 'last-AP', 'day-NN', 'for-IN', 'early-NN', 'voting!-NN', 'ready,-NN', 'set-VB', '&-CC-TL', 'vote!-NN', '!-.']
# ['i’ll-NN', 'be-BE', 'in-IN', 'poland-NP', 'but-CC', 'back-RB', 'sunday-NR', 'eve,-NN', 'catch-VB', 'you-PPSS', 'then!-NN']
# ['observers-NNS', 'from-IN', 'un,-NN', 'eu,-NN', 'cw,-NN', 'send-VB', 'to-TO', 'coni-NN', ',-,', 'according-IN', 'to-TO', 'this-DT', 'observers-NNS', 'what-WDT', 'the-AT', 'maldivian-NN', 'have-HV', 'seen-VBN', 'live-VB', 'and-CC', 'on-IN', 'tvs-NN', 'on-IN', '7-CD', 'feb-NN', 'are-BER', 'day-NN', 'dream,-NN']
# ['fuck-NN', 'halloween.-NN', 'fuck-VB', 'thanksgiving.-NN', 'fuck-VB', 'my-PP$', 'birthday.-NN', 'fuck-VB', 'christmas,-NN', 'the-AT', 'new-JJ-TL', 'year,-NN', 'valentines,-NN', 'st.-NN-TL', 'patrick’s,-NN', 'april-NP', 'fools.-NN', 'fuck-VB', 'all-ABN', 'of-IN', 'that.-NN']
# ['"my-NN', 'mother-NN', 'just-RB', 'said-VBD', '\\""""what’s-NN', 'gucci-NN', 'mah-PP$', 'nigguh!\\""""-NN', 'to-TO', 'me,-NN', 'i-NN', 'think-VB', 'she-PPS', 'may-MD', 'have-HV', 'been-BEN', 'listening-VBG', 'to-TO', '\\""""niggas-NN', 'in-IN', 'paris\\"""",-NN', 'should-MD', 'i-NN', 'be-BE', 'worried?"-NN']
# ['going-VBG', 'to-TO', 'the-AT', 'grammys-NN', 'first-OD-TL', 'entertainment-NN', 'law-NN', 'breakfast-NN', 'here-RB', 'in-IN', 'nyc-NN', 'tomorrow!-NN', 'i’m-NN', 'so-QL', 'excited.-NN', 'one-CD', 'step-NN', 'closer...-NN']
# ['good-JJ', 'morning-NN', 'becky.-NN', 'hope-NN-TL', 'all’s-NN', 'well,-NN', 'may-MD', 'you-PPSS', 'all-ABN', 'have-HV', 'a-AT', 'good-JJ', 'day-NN']
# ['amazon-NP', 'has-HVZ', 'opened-VBD', 'an-AT', 'online-NN', 'store-NN', 'for-IN', 'black-NP', 'friday-NR', '22-CD', 'days-NNS', 'before-CS', 'the-AT', 'shopping-VBG', 'event-NN', 'is-BEZ', 'scheduled-VBN', 'to-TO', 'take-VB', 'place.-NN']
# ['i-PPSS', 'may-MD', 'have-HV', 'done-VBN', 'a-AT', 'dumb-JJ', 'thing,-NN', 'but-CC', 'it’s-NN', 'out-RP', 'there-EX', 'now.-NN', 'my-PP$', 'new,-NN', 'long-JJ', 'term-NN', 'goal:-NN', 'the-AT', 'challenge-NN-TL']
# ['i-PPSS', 'think-VB', 'i-PPSS', 'may-MD', 'be-BE', 'the-AT', 'only-RB', 'person-NN', 'around-IN', 'not-*', 'excited-VBN', 'that-CS', 'beyonce-NN', 'is-BEZ', 'the-AT', 'half-ABN', 'time-NN', 'performer-NN', 'for-IN', 'the-AT', 'superbowl.-NN']
# ['chicago:-NN', 'go-VB', 'see-VB', ':-:', 'october-NP', '27th-OD', '7p-NN', 'at-IN', 'the-AT', '47th-NN', '&-CC-TL', 'king-NN-TL', 'dr.-NN-TL']
# ['happy-JJ-TL', 'thursday!-NN', 'enjoyed-NN', 'the-AT', 'show-VB', 'so-QL', 'much-AP', 'last-AP', 'night-NN', 'watched-VBD', '4x.-NN', '!!-NN', 'have-HV', 'a-AT', 'great-JJ', 'day-NN', 'my-PP$', 'greek!-NN']
# ['a-AT', 'three-month-old-NN', 'boy-NN', 'was-BEDZ', 'found-VBD', 'abandoned-VBN', 'at-IN', 'a-AT', 'platform-NN', 'of-IN', 'the-AT', 'chhatrapati-NN', 'shivaji-NN', 'terminus-NN', '(cst)-NN', 'on-IN', 'saturday-NR', 'night.-NN']
# ['highlight-NN', 'of-IN', 'monday-NN', 'was-BEDZ', 'chucking-VBG', 'a-AT', 'mattress-NN', 'down-RP', 'the-AT', 'stairs-NNS', 'which-WDT', 'hit-VBD', 'eleanor-NN', 'around-IN', 'the-AT', 'face,-NN', 'causing-VBG', 'her-PP$', 'to-TO', 'fall-NN', 'down-RP', 'the-AT', 'stairs-NNS']
# ['the-AT', 'fact-NN', 'that-CS', 'i-PPSS', 'have-HV', 'no-AT', 'plans-NNS', 'tomorrow-NR', 'night-NN', '&-CC-TL', 'it’s-NN', 'my-PP$', 'last-AP', 'night-NN', 'in-IN', 'fl-NN', 'for-IN', 'a-AT', 'min-NN', '<<<<<<-NN']
# ['wow-UH', 'busy!-NN', 'just-RB', 'saw-VBD', 'the-AT', 'promo-NN', 'on-IN', 'tbs-NN', 'for-IN', 'cougar-NN', 'town-NN-TL', 'in-IN', 'jan.-NP', 'you-PPSS', 'are-BER', 'absolutely-QL', 'a-AT', 'vision,-NN', 'an-AT', 'angel-NN-TL', 'in-IN', 'white!-NN', 'beautiful!!!!!!!-NN']
# ['boogie-NN-TL', 'song-NN', 'of-IN', 'the-AT', 'day...oh-NN', 'ricky-NN', 'martin:-NN', 'que-NN', 'mas-NN', 'da-NP', 'happy-JJ-TL', 'sunday-NR', '2-CD', 'everyone-PN', 'recovering-VBG', 'from-IN', 'halloween-NP', 'party-NN', 'hangovers-NNS']
# ['loved-NN', 'the-AT', 'hair-NN', 'style-NN', 'from-IN', 'friday’s-NN', 'jason-NP', 'wu-NP', 'show?-NN', 'we’re-NN', 'giving-VBG', 'you-PPSS', 'the-AT', 'step-by-step-JJ', 'to-TO', 'recreate-VB', 'the-AT', 'look-VB']
# ['sad-JJ', 'to-TO', 'say-VB', 'nearly-RB', 'at-IN', 'an-AT', 'end.-NN', 'fantastic-JJ', 'event-NN', 'last-AP', 'night-NN', 'with-IN', 'michael-NP', 'portillo.-NN', 'last-AP', 'event-NN', 'tomorrow-NR', 'with-IN', 'charles-NP', 'dickens.-NN']
# ['glad-JJ', 'you-PPSS', 'do.-NN', 'i-PPSS', 'think-VB', 'he-PPS', 'may-MD', 'even-RB', 'be-BE', 'the-AT', 'next-AP', 'spurs-NN', 'player-NN', 'to-TO', 'leave-VB', 'for-IN', 'a-AT', 'really-RB', 'big-JJ', 'club.-NN', 'before-CS', 'bale-NN', 'possibly.-NN']
# ['yeah-RB', 'your-PP$', 'game-NN', 'against-IN', 'the-AT', 'ravens-NN', 'was-BEDZ', 'a-AT', 'thursday-NR', 'night-NN', 'game.-NN', 'im-NN', 'sure-JJ', 'you-PPSS', 'will-MD', 'pull-VB', 'for-IN', 'the-AT', 'giants-NNS-TL', 'these-DTS', 'next-AP', '2-CD', 'games-NNS']
# ['just-RB', 'landed-VBD', 'in-IN', 'las-NP', 'vegas!!!-NN', 'so-RB', 'excited-VBN', 'to-TO', 'start-VB', 'canvassing-NN', 'for-IN', 'obama-NN', 'tomorrow-NR', 'with-IN', 'and-CC', '!-.', ':)-NN']
# ['i-NN', 'remember-VB', 'when-WRB', 'i-NN', 'was-BEDZ', 'at-IN', 'cadet-NN', 'camp-NN', 'once(aye,wat-NN', 'u-PPO', 'sayin)-NN', 'and-CC', 'we-PPSS', 'were-BED', 'watching-VBG', 'a-AT', 'video-NN', 'and-CC', 'kasabian-NN', 'came-VBD', 'on-IN', 'and-CC', 'i-NN', 'just-RB', 'sat-VBD', 'singing-VBG']
# ['1st-NN', 'its-PP$', 'like-CS', 'imma-NN', 'play-VB', 'headlock,-NN', 'and-CC', 'then-RB', 'safe-NN', 'and-CC', 'sound,-NN', 'and-CC', 'now-RB', 'you-PPSS', 'gonna-VBG+TO', 'play-VB', 'all-ABN', 'star.-NN', 'hmmmm-NN']
# ['okay-UH', 'it’s-NN', 'late...-NN', 'going-VBG', 'off-RP', ':)-NN', 'will-MD', 'send-VB', 'jennette-NN', 'tomorrow-NR', 'more-QL', 'names-NNS', ':)-NN', 'good-JJ', 'night-NN', ':)-NN']
# ['defenders-NNS', 'stephen-NP', 'bowen,-NN', 'barry-NP', 'cofield-NN', 'and-CC', 'rob-NP', 'jackson-NP', 'swarm-NN', 'manning-NP', 'on-IN', '1st-NN', 'down!-NN', 'cofield-NN', 'and-CC', 'jackson-NP', 'credited-VBN', 'with-IN', 'sack!-NN']
# ['close-RB', 'early-JJ', 'on-IN', 'thanksgiving-NN-TL', 'eve.-NN', 'decorate-NN', 'like-CS', 'the-AT', 'dickens.-NN', 'thanksgiving-NN-TL', 'day-NN-TL', 'off!-NN', 'boom.-NN', 'store-NN-TL', 'all-ABN', 'christmas-NP', 'for-IN', 'friday.-NN']
# ['dad:-NN', 'what-WDT', 'are-BER', 'you-PPSS', 'going-VBG', 'to-TO', 'do-DO', 'in-IN', 'athens-NP', 'tomorrow?-NN', 'me:-NN', 'nothing.-NN', 'dad:-NN', 'oh.-NN', 'ok.-NN', 'have-HV', 'fun.-NN', 'i-PPSS', 'like-CS', 'my-PP$', 'father.-NN']
# ['don’t-NN', 'be-BE', 'surprised-VBN', 'if-CS', 'we-PPSS', 'end-NN', 'up-RP', 'waiting-VBG', 'until-CS', 'november-NP', '16th-OD', 'to-TO', 'find-VB', 'out-RP', 'who-WPS', 'the-AT', 'next-AP', 'potus-NN', 'is...-NN']
# ['rugby-NN', 'tonight-NR', 'and-CC', 'it’s-NN', 'like-CS', 'freezing-VBG', 'omg-NN', 'i-PPSS', 'may-MD', 'die-VB']
# ['no-AT', 'wonder-VB', 'coming-VBG', 'here-RB', 'the-AT', '21st-OD', 'of-IN', 'nov-NN', 'cause-NN', 'he-PPS', 'got-VBD', 'soul-NN', 'train-NN-TL', 'the-AT', '25th-OD']
# ['i-PPSS', 'hope-NN', 'the-AT', 'plane-NN', 'home-NR', 'tomorrow-NR', 'has-HVZ', 'cougar-NN', 'town-NN-TL', 'and-CC', 'friends-NNS-TL', 'on-IN', 'the-AT', 'tvs.-NN', 'that’s-NN', 'how-WRB', 'i-PPSS', 'spent-VBN', 'most-QL', 'of-IN', 'the-AT', 'time-NN', 'flying-VBG', 'here-RB', 'xd-NN']
# ['you-PPSS', 'going-VBG', 'to-TO', 'rugby-NN', 'practice-NN', 'on-IN', 'sunday-NN']
# ['results-NNS', 'live-VB', 'at-IN', '10pm-NN', 'on-IN', 'channel-NN-TL', '4.-NN', 'if-CS', 'you-PPSS', 'have-HV', '4-CD', 'music-NN-TL', 'its-PP$', 'on-IN', 'there-EX', 'from-IN', '9.45.-NN', 'lets-NN', 'get-VB', 'tanked-NN', 'up-RP', 'tomorrow-NR', 'either-CC', 'way!-NN']
# ['asia-NP', 'stocks-NNS', 'mostly-RB', 'up-RP', 'on-IN', 'us,-NN', 'china-NP', 'data:-NN', 'asian-JJ', 'stock-NN', 'markets-NNS', 'advanced-VBN', 'friday-NR', 'as-CS', 'a-AT', 'batch-NN', 'of-IN', 'upbeat-JJ', 'economic-JJ', 'data-NNS', 'from-IN', 'the-AT', 'u.s.-NP', 'and-CC', 'chi...-NN']
# ['breaking-VBG', 'dawn-NN-TL', 'is-BEZ', 'coming-VBG', 'out-RP', 'on-IN', 'the-AT', '16th-OD', ',-,', 'yayyy-NN']
# ['dive-NN', 'deep-JJ', 'into-IN', 'the-AT', 'worlds-NNS', 'of-IN', 'stefan-NN', 'struve-NN', 'and-CC', 'stipe-NN', 'miocic-NN', 'leading-VBG', 'to-TO', 'their-PP$', 'fuel-NN', 'tv-NN', 'main-JJS', 'event-NN', 'this-DT', 'saturday.-NN']
# ['i’m-NN', 'pretty-QL', 'sure-JJ', 'bill-NP', 'o𠆛rien-NN', 'has-HVZ', 'gone-VBN', 'for-IN', 'it-PPS', 'on-IN', '4th-OD', 'down-RP', 'more-QL', 'in-IN', 'one-CD', 'season-NN', 'than-CS', 'paterno-NN', 'did-DOD', 'his-PP$', 'entire-JJ', 'career.-NN']
# ['got-VBD', 'my-PP$', 'tix-NN', 'to-TO', 'victory-NN-TL', 'rally-NN', 'w/-NN', 'mitt,-NN', 'ann-NP', '&-CC-TL', 'the-AT', 'gop-NN', 'team-NN', 'at-IN', 'fiddler’s-NN', 'green-NP', 'on-IN', 'saturday.-NN', 'should-MD', 'be-BE', 'a-AT', 'monster-NN', 'hoot.-NN']
# ['the-AT', 'painting-VBG', 'project-NN', 'continues-VBZ', 'today-NR', 'and-CC', 'is-BEZ', 'to-TO', 'be-BE', 'completed-VBN', 'on-IN', 'nov-NN', '10-CD', 'and-CC', '17.-NN', 'please-VB', 'join-VB', 'coni-NN', 'in-IN', 'partnering-VBG', 'to-TO', 'give-VB', 'back-RB', 'to-TO', 'the-AT', 'community.-NN']
# ['celebrate-NN', 'the-AT', 'chinese-JJ', 'new-JJ-TL', 'year-NN-TL', 'in-IN', '(around-NN', 'february)-NN', 'and-CC', 'see-VB', 'a-AT', 'dragon-NN', 'dance-NN', 'during-IN', 'the-AT', 'spring-NN-TL', 'festival!-NN', 'amazing-VBG', 'experience!-NN']
# ['disappointing-VBG', 'to-TO', 'see-VB', 'the-AT', 'uk-NN', 'govt-NN', 'issueing-VBG', 'reassuring-VBG', 'messages-NNS', 'to-TO', 'tehran-NN', 'maybe-RB', 'they-PPSS', 'were-BED', 'influenced-VBN', 'by-IN', ':)-NN']
# ['if-CS', 'anyone-PN', 'wants-VBZ', 'to-TO', 'go-VB', 'to-TO', 'the-AT', 'duke-NN', 'game-NN', 'saturday-NR', 'with-IN', 'the-AT', 'kershaw-NN', 'county-NN', 'clemson-NN', 'club-NN', 'please-VB', 'inbox-NN', 'me!-NN']
# ['heavy-JJ-HL', 'rain-NN', 'over-IN', 'parts-NNS', 'of-IN', 'ne.-NN', 'some-DTI', 'showers-NNS', 'in-IN', 'cny.-NN', 'any-DTI', 'sun?-NN', 'how-WRB', 'about-IN', 'the-AT', 'weekend?-NN', 'your-PP$', 'forecast-VBN', 'first-NN', 'at-IN', '4am-NN', 'on-IN', 'nbc-3!-NN']
# ['##$$##-NN', 'black-NP', 'friday-NR', 'deals-NN', 'olympus-NN', 'om-d-NN', 'e-m5-NN', 'digital-NN', 'camera-NN-TL', '--IN', 'black-NP', '--IN', 'with-IN', 'olympus-NN', '12-50mm-NN', 'f/3.5-5.6-NN', 'ez-NN', 'zoom-NN', 'lens-NN', '--IN', 'b...-NN']
# ['you-PPSS', 'beat-VB', 'them-PPO', '5-1-CD-TL', 'in-IN', 'the-AT', 'san-NP', 'siro-NN', 'but-CC', 'terry-NP', 'henrys-NN', '3rd-OD', 'goal-NN', 'is-BEZ', 'world-NN', 'class.-NN', '!-.']
# ['"niggas-NN', 'is-BEZ', 'goin-VBG', 'die-VB', 'on-IN', 'december-NP', '26th-OD', 'when-WRB', 'them-PPO', 'foams-NNS', 'come-VB', 'out-RP', '..-NN', 'lol-NN', 'rs-NN', '..-NN', 'niggas-NN', 'goin-VBG', 'rob-VB', 'you-PPSS', '&-CC-TL', 'be-BE', 'like-CS', '\\""""da-NN', 'shoes-NNS', 'or-CC', 'ya-PPSS', 'life-NN', 'nigga\\""""-NN', 'lol"-NN']
# ['more-AP', 'footage-NN', 'from-IN', 'the-AT', 'studio-NN', 'where-WRB', 'bullet-NN-TL', 'for-IN', 'my-PP$', 'valentine-NP-TL', 'just-RB', 'finished-VBN', 'up-RP', 'recording-VBG', 'their-PP$', 'upcoming-JJ', '4th-OD', 'album....-NN']
# ['just-RB', 'bought-VBD', 'my-PP$', '1st-NN', 'heineken-NN', 'beer-NN', 'in-IN', 'las-NP', 'vegas.-NN', 'ps-NN', 'i’ve-NN', 'lived-VBD', 'here-RB', 'for-IN', '5-CD', 'yrs-NN', '~what-NN', 'took-VBD', 'me-PPO', 'so-QL', 'long!-NN']
# ['20-CD', 'june-NP', '2012,-NN', 'out-RP', 'european-JJ', 'tour-FW-NN-TL', 'party-NN', 'drove-VBD', 'the-AT', 'fabulous-JJ', 'road-NN', 'from-IN', 'davos-NN', 'to-TO', 'stelvio.-NN', 'this-DT', 'is-BEZ', 'the-AT', 'last-AP', 'little-AP', 'bit...-NN']
# ['join-VB', 'us-PPO', 'this-NN', 'thursday-NN', 'for-IN', 'the-AT', 'introduction-NN-HL', 'to-TO', 'our-PP$', 'dramatic-JJ', 'reading-VBG', 'of-IN', 'charles-NP', 'dickens’s-NN', 'a-AT', 'christmas-NP', 'carol.-NN', '11/1-NN', '6-7pm.-NN']
# ['can’t-NN', 'wait-VB', 'for-IN', 'the-AT', 'new-JJ', 'series,-NN', 'starts-VBZ', 'on-IN', 'sunday-NR', 'over-IN', 'here-RB', 'in-IN', 'britain,-NN']
# ['saw-VBD', 'this-DT', 'an-AT', 'it-PPS', 'made-VBN', 'me-PPO', 'think-VB', 'of-IN', 'cougar-NN', 'town...-NN', 'can’t-NN', 'wait-VB', 'for-IN', 'january!!!-NN']
# ['"published-NN', 'a-AT', 'new-JJ', 'blog-NN', 'entry-NN', 'november-NP', '18-CD', '--IN', '\\""""otherwise-NN', 'known-NN', 'as-CS', 'sheila-NP', 'the-AT', 'great\\""""-NN', 'in-IN', 'art-NN-TL', 'in-IN', 'the-AT', 'county.-NN']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
positive_tweets = [content for [tag, sentiment, content] in train_ if sentiment == "positive"]
negative_tweets = [content for [tag, sentiment, content] in train_ if sentiment == "negative"]
neutral_tweets = [content for [tag, sentiment, content] in train_ if sentiment == "neutral"]

positive_tokens_for_model = get_tweets_for_model(positive_tweets)
negative_tokens_for_model = get_tweets_for_model(negative_tweets)
neutral_tokens_for_model = get_tweets_for_model(neutral_tweets)

positive_dataset = [(tweet_dict, "positive") for tweet_dict in positive_tokens_for_model]
negative_dataset = [(tweet_dict, "negative") for tweet_dict in negative_tokens_for_model]
neutral_dataset = [(tweet_dict, "neutral") for tweet_dict in neutral_tokens_for_model]

train_dataset = positive_dataset + negative_dataset + neutral_dataset

# %% [markdown]
# Das gleiche ebenfalls für das Test-Dataset:

# %%
positive_test_tweets = [content for [tag, sentiment, content] in test_ if sentiment == "positive"]
negative_test_tweets = [content for [tag, sentiment, content] in test_ if sentiment == "negative"]
neutral_test_tweets = [content for [tag, sentiment, content] in test_ if sentiment == "neutral"]

positive_test_tokens_for_model = get_tweets_for_model(positive_test_tweets)
negative_test_tokens_for_model = get_tweets_for_model(negative_test_tweets)
neutral_test_tokens_for_model = get_tweets_for_model(neutral_test_tweets)

positive_test_dataset = [(tweet_dict, "positive") for tweet_dict in positive_test_tokens_for_model]
negative_test_dataset = [(tweet_dict, "negative") for tweet_dict in negative_test_tokens_for_model]
neutral_test_dataset = [(tweet_dict, "neutral") for tweet_dict in neutral_test_tokens_for_model]

test_dataset = positive_test_dataset + negative_test_dataset + neutral_test_dataset

# %% [markdown]
# Als Resultant haben wir dann:

# %%
tagged_classifier = NaiveBayesClassifier.train(train_dataset)

tagged_accuracy = classify.accuracy(tagged_classifier, test_dataset)

print("Accuracy is:", tagged_accuracy)

print(tagged_classifier.show_most_informative_features(20))
# Out:
# Accuracy is: 0.5390470820411616
# Most Informative Features
#                  fuck-VB = True           negati : neutra =     70.2 : 1.0
#                   fun-NN = True           positi : neutra =     34.0 : 1.0
#              happy-JJ-TL = True           positi : neutra =     33.3 : 1.0
#                  luck-NN = True           positi : neutra =     33.2 : 1.0
#                 thank-VB = True           positi : neutra =     32.3 : 1.0
#              excited-VBN = True           positi : neutra =     26.5 : 1.0
#                 happy-JJ = True           positi : neutra =     26.0 : 1.0
#               awesome-JJ = True           positi : neutra =     25.6 : 1.0
#                 great-JJ = True           positi : neutra =     24.6 : 1.0
#                 sorry-JJ = True           negati : neutra =     24.5 : 1.0
#                  hate-VB = True           negati : positi =     24.5 : 1.0
#                   sad-JJ = True           negati : neutra =     23.3 : 1.0
#                    :(-NN = True           negati : neutra =     23.2 : 1.0
#                  damn-VB = True           negati : neutra =     22.0 : 1.0
#              fucking-VBG = True           negati : neutra =     20.7 : 1.0
#                  cant-NN = True           positi : neutra =     20.6 : 1.0
#                    :)-NN = True           positi : negati =     19.7 : 1.0
#              great-JJ-TL = True           positi : neutra =     19.4 : 1.0
#          republicans-NPS = True           negati : positi =     19.1 : 1.0
#                  cool-JJ = True           positi : neutra =     18.9 : 1.0
# None

# %% [markdown]
# Die resultierende Accuracy ist (minimal) niedriger als die Accuracy der Baseline ohne Lemmatisierung. Dies ist zu erwarten, da verschiedene Wortformmen des gleichen Wortstammes bei informativen Wortstammen keinen großen Einfluss auf das Sentiment haben. Da jedoch durch das POS-Tagging beim Bayes-Klassifizier als unterschiedliche Features betrachtet werden, stehen dem Klassifizierer weniger Trainingsdaten zur Verfügung. Weiterhin betrachtet der Tagger nicht Kontraktionen (z.B. he'd, can't, we'll, it's, won't,...). Als Resultat ist die Accuracy minimal schlechter. Es lohnt sich also nur, den Klassifizierter auf lemmatisierte Datensätze zu trainieren, aber nicht auf getaggte.
#
# Erwähnenswert ist, dass das Aufkommen des Feature "fuck-VB" im Vergleich zu den vorherigen Klassifizierern einen betrachtlicheren Informationsgewinn einnimmt. Unter Betrachtung des POS-tags (und ohne Lemmatisierung) verdoppelt sich nahehin die Rate, in der sich dieses Feature in negativen Tweets finden lässt.

# %% [markdown]
# Neben der Baseline, in der ein Bayes-Klassifizierer auf das gesamte Test-Dataset trainiert wird, wird ebenfalls noch ein Bayes-Klassifizierer nur auf die häufigsten Wörter trainiert, die jeweils (fast nur) in positiven, negativen, und neutralen Tweets auftauchen. Da der Baseline somit mehr Trainingsdaten zur Verfügung stehen, ist es nicht überraschend dass diese besser ausfällt als das zweite Verfahren:

# %%
print("Klassifizierer auf alle Wörter trainiert: " + str(accuracy))
print("Klassifizierer auf frequente Wörter trainiert: " + str(accuracy2))
# Out:
# Klassifizierer auf alle Wörter trainiert: 0.5841556244713842
# Klassifizierer auf frequente Wörter trainiert: 0.558782069354384
